# %%
import importlib
import os, pandas as pd, numpy as np
from joblib import dump, load

import sys
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import sod.core.dataset as sod_core_dataset
importlib.reload(sod_core_dataset)
import sod.core.plot as sod_plot
importlib.reload(sod_plot)
# from sod.core.dataset import open_dataset # , normalize_df
# from sod import plot

is_outlier = sod_core_dataset.is_outlier

maindir = os.path.abspath(os.path.join(os.getcwd(), '..', 'evaluations/results/cv.allset_train.iforest.2.yaml/'))
assert os.path.isdir(maindir)

evalreports = os.path.join(maindir, 'evalreports')
assert os.path.isdir(evalreports)

# create evaluations all:
import sod.core.evaluation as sod_core_eval
importlib.reload(sod_core_eval)

print('Creating evaluations all (html) in %s' % evalreports)
sod_core_eval.aggeval(evalreports, format='html')


print('Creating evaluations all (hdf) in %s' % evalreports)
sod_core_eval.aggeval(evalreports, format='hdf')

# If you want to read the evaluation dataframe:

#path = os.path.join(evalreports, 'evaluations.all.hdf')
# dfr = pd.read_hdf(path)
# print('evaulation dataframe.\n\nColumns:\n' + str(dfr.columns.tolist()))
# print('\nclassname distinct values:\n' + str(np.unique(dfr['classname'])))
# Out:
# Creating evaluations all (html) in /Users/riccardo/work/gfz/projects/sources/python/sod/sod/evaluations/results/cv.allset_train.iforest.2.yaml/evalreports
#
# Creating evaluations all (hdf) in /Users/riccardo/work/gfz/projects/sources/python/sod/sod/evaluations/results/cv.allset_train.iforest.2.yaml/evalreports
#       % rec.  Mean log_loss behaviour                        classname  \
# 0     88.461        0.59011       new                               ok
# 1     96.110        0.39399       new                outl. (wrong inv)
# 2     37.282        0.72654       new  unlabeled (Me suspicious outl.)
# 3     88.154        0.60060       new           unlabeled (Me unknown)
# 4     91.586        0.57686       new                               ok
# 5     96.775        0.34889       new                outl. (wrong inv)
# 6     34.449        0.74147       new  unlabeled (Me suspicious outl.)
# 7     89.377        0.58568       new           unlabeled (Me unknown)
# 8     94.014        0.55211       new                               ok
# 9     96.068        0.34654       new                outl. (wrong inv)
# 10    33.609        0.74201       new  unlabeled (Me suspicious outl.)
# 11    92.516        0.58109       new           unlabeled (Me unknown)
# 12    95.518        0.53952       new                               ok
# 13    95.390        0.35341       new                outl. (wrong inv)
# 14    29.302        0.77608       new  unlabeled (Me suspicious outl.)
# 15    93.876        0.55578       new           unlabeled (Me unknown)
# 16    89.931        0.58206       new                               ok
# 17    97.335        0.36902       new                outl. (wrong inv)
# 18    38.740        0.71522       new  unlabeled (Me suspicious outl.)
# 19    86.435        0.60944       new           unlabeled (Me unknown)
# 20    92.265        0.56600       new                               ok
# 21    96.946        0.37130       new                outl. (wrong inv)
# 22    36.277        0.73509       new  unlabeled (Me suspicious outl.)
# 23    88.644        0.59688       new           unlabeled (Me unknown)
# 24    93.225        0.55936       new                               ok
# 25    96.605        0.35804       new                outl. (wrong inv)
# 26    33.101        0.74414       new  unlabeled (Me suspicious outl.)
# 27    90.632        0.58474       new           unlabeled (Me unknown)
# 28    95.689        0.53715       new                               ok
# 29    96.510        0.35168       new                outl. (wrong inv)
# ...      ...            ...       ...                              ...
# 1458  40.617        0.65520       new  unlabeled (Me suspicious outl.)
# 1459  91.186        0.62980       new           unlabeled (Me unknown)
# 1460  91.191        0.60351       new                               ok
# 1461  98.297        0.23025       new                outl. (wrong inv)
# 1462  35.167        0.68309       new  unlabeled (Me suspicious outl.)
# 1463  93.975        0.60856       new           unlabeled (Me unknown)
# 1464  92.060        0.59400       new                               ok
# 1465  98.270        0.23781       new                outl. (wrong inv)
# 1466  35.222        0.68252       new  unlabeled (Me suspicious outl.)
# 1467  93.898        0.61230       new           unlabeled (Me unknown)
# 1468  93.900        0.58501       new                               ok
# 1469  98.071        0.26244       new                outl. (wrong inv)
# 1470  33.764        0.69787       new  unlabeled (Me suspicious outl.)
# 1471  94.255        0.60561       new           unlabeled (Me unknown)
# 1472  88.229        0.61825       new                               ok
# 1473  98.641        0.23697       new                outl. (wrong inv)
# 1474  41.302        0.65798       new  unlabeled (Me suspicious outl.)
# 1475  90.727        0.61950       new           unlabeled (Me unknown)
# 1476  90.885        0.59777       new                               ok
# 1477  98.560        0.23900       new                outl. (wrong inv)
# 1478  39.524        0.67915       new  unlabeled (Me suspicious outl.)
# 1479  91.896        0.61015       new           unlabeled (Me unknown)
# 1480  91.759        0.60016       new                               ok
# 1481  98.329        0.23037       new                outl. (wrong inv)
# 1482  35.686        0.67919       new  unlabeled (Me suspicious outl.)
# 1483  93.801        0.61417       new           unlabeled (Me unknown)
# 1484  93.232        0.59101       new                               ok
# 1485  98.248        0.26198       new                outl. (wrong inv)
# 1486  34.852        0.70072       new  unlabeled (Me suspicious outl.)
# 1487  94.019        0.60553       new           unlabeled (Me unknown)
#
#                   clf contamination  \
# 0     IsolationForest          auto
# 1     IsolationForest          auto
# 2     IsolationForest          auto
# 3     IsolationForest          auto
# 4     IsolationForest          auto
# 5     IsolationForest          auto
# 6     IsolationForest          auto
# 7     IsolationForest          auto
# 8     IsolationForest          auto
# 9     IsolationForest          auto
# 10    IsolationForest          auto
# 11    IsolationForest          auto
# 12    IsolationForest          auto
# 13    IsolationForest          auto
# 14    IsolationForest          auto
# 15    IsolationForest          auto
# 16    IsolationForest          auto
# 17    IsolationForest          auto
# 18    IsolationForest          auto
# 19    IsolationForest          auto
# 20    IsolationForest          auto
# 21    IsolationForest          auto
# 22    IsolationForest          auto
# 23    IsolationForest          auto
# 24    IsolationForest          auto
# 25    IsolationForest          auto
# 26    IsolationForest          auto
# 27    IsolationForest          auto
# 28    IsolationForest          auto
# 29    IsolationForest          auto
# ...               ...           ...
# 1458  IsolationForest          auto
# 1459  IsolationForest          auto
# 1460  IsolationForest          auto
# 1461  IsolationForest          auto
# 1462  IsolationForest          auto
# 1463  IsolationForest          auto
# 1464  IsolationForest          auto
# 1465  IsolationForest          auto
# 1466  IsolationForest          auto
# 1467  IsolationForest          auto
# 1468  IsolationForest          auto
# 1469  IsolationForest          auto
# 1470  IsolationForest          auto
# 1471  IsolationForest          auto
# 1472  IsolationForest          auto
# 1473  IsolationForest          auto
# 1474  IsolationForest          auto
# 1475  IsolationForest          auto
# 1476  IsolationForest          auto
# 1477  IsolationForest          auto
# 1478  IsolationForest          auto
# 1479  IsolationForest          auto
# 1480  IsolationForest          auto
# 1481  IsolationForest          auto
# 1482  IsolationForest          auto
# 1483  IsolationForest          auto
# 1484  IsolationForest          auto
# 1485  IsolationForest          auto
# 1486  IsolationForest          auto
# 1487  IsolationForest          auto
#
#                                               features  max_samples  \
# 0     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 1     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 2     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 3     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 4     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 5     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 6     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 7     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 8     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 9     psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 10    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 11    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 12    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# 13    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# 14    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# 15    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# 16    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 17    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 18    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 19    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512
# 20    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 21    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 22    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 23    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         1024
# 24    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 25    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 26    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 27    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048
# 28    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# 29    psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         4096
# ...                                                ...          ...
# 1458                                          psd@5sec          512
# 1459                                          psd@5sec          512
# 1460                                          psd@5sec         1024
# 1461                                          psd@5sec         1024
# 1462                                          psd@5sec         1024
# 1463                                          psd@5sec         1024
# 1464                                          psd@5sec         2048
# 1465                                          psd@5sec         2048
# 1466                                          psd@5sec         2048
# 1467                                          psd@5sec         2048
# 1468                                          psd@5sec         4096
# 1469                                          psd@5sec         4096
# 1470                                          psd@5sec         4096
# 1471                                          psd@5sec         4096
# 1472                                          psd@5sec          512
# 1473                                          psd@5sec          512
# 1474                                          psd@5sec          512
# 1475                                          psd@5sec          512
# 1476                                          psd@5sec         1024
# 1477                                          psd@5sec         1024
# 1478                                          psd@5sec         1024
# 1479                                          psd@5sec         1024
# 1480                                          psd@5sec         2048
# 1481                                          psd@5sec         2048
# 1482                                          psd@5sec         2048
# 1483                                          psd@5sec         2048
# 1484                                          psd@5sec         4096
# 1485                                          psd@5sec         4096
# 1486                                          psd@5sec         4096
# 1487                                          psd@5sec         4096
#
#       n_estimators
# 0               50
# 1               50
# 2               50
# 3               50
# 4               50
# 5               50
# 6               50
# 7               50
# 8               50
# 9               50
# 10              50
# 11              50
# 12              50
# 13              50
# 14              50
# 15              50
# 16             100
# 17             100
# 18             100
# 19             100
# 20             100
# 21             100
# 22             100
# 23             100
# 24             100
# 25             100
# 26             100
# 27             100
# 28             100
# 29             100
# ...            ...
# 1458           100
# 1459           100
# 1460           100
# 1461           100
# 1462           100
# 1463           100
# 1464           100
# 1465           100
# 1466           100
# 1467           100
# 1468           100
# 1469           100
# 1470           100
# 1471           100
# 1472           200
# 1473           200
# 1474           200
# 1475           200
# 1476           200
# 1477           200
# 1478           200
# 1479           200
# 1480           200
# 1481           200
# 1482           200
# 1483           200
# 1484           200
# 1485           200
# 1486           200
# 1487           200
#
# [1488 rows x 9 columns]
