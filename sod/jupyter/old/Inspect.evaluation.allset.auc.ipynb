# %%
import importlib
import os, pandas as pd, numpy as np
from joblib import dump, load

import sys
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
import sod.core.dataset as sod_core_dataset
importlib.reload(sod_core_dataset)
import sod.core.plot as sod_plot
importlib.reload(sod_plot)
# from sod.core.dataset import open_dataset # , normalize_df
# from sod import plot

is_outlier = sod_core_dataset.is_outlier

maindir = os.path.abspath(os.path.join(os.getcwd(), '..', 'evaluations/results/cv.allset_train.iforest.yaml/'))
assert os.path.isdir(maindir)

evalreports = os.path.join(maindir, 'evalreports')
assert os.path.isdir(evalreports)

# create evaluations all:
import sod.core.evaluation as sod_core_eval
importlib.reload(sod_core_eval)

print('Creating evaluations all (html)')
sod_core_eval.aggeval(evalreports, format='html')

print('Creating evaluations all (hdf)')
sod_core_eval.aggeval(evalreports, format='hdf')

path = os.path.join(evalreports, 'evaluations.all.hdf')

dfr = pd.read_hdf(path)
print('evaulation dataframe.\n\nColumns:\n' + str(dfr.columns.tolist()))
print('\nclassname distinct values:\n' + str(np.unique(dfr['classname'])))
# Out:
# Creating evaluations all (html)
# Creating evaluations all (hdf)
# evaulation dataframe.
#
# Columns:
# ['% rec.', 'Mean log_loss', 'behaviour', 'classname', 'clf', 'contamination', 'features', 'max_samples', 'n_estimators']
#
# classname distinct values:
# ['ok' 'outl. (wrong inv)' 'unlabeled (Me suspicious outl.)'
#  'unlabeled (Me unknown)']

# %%
# Some tries to embed the html page, NOT WORKING

# from IPython.display import IFrame
# IFrame(src='file://' + os.path.join(maindir, 'evaluations.all.html'), width=700, height=600)

# from IPython.display import Javascript
# %%javascript
# from IPython.core.display import display, HTML
# display(HTML(open(os.path.join(maindir, 'evaluations.all.html')).read()))

clfs = {}
preds = {}
for modelname in os.listdir(os.path.join(maindir, 'models')):
    name = os.path.splitext(modelname)[0]
    modelpath = os.path.join(maindir, 'models', modelpath)
    predictionspath = os.path.join(maindir, 'predictions', name + '.hdf')
    if not os.path.isfile(predictionspath):
        print(' Not found: %s' % os.path.basename(predictionspath))
        continue
    print('Loading: %s' % name)
    clfs[name] = load(os.path.join(maindir, 'models', modelpath))
    preds[name] = pd.read_hdf(predictionspath)
# Out:
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=16384&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=8192&n_estimators=200&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=16384&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=100&behaviour=new.hdf
#  Not found: IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=8192&n_estimators=200&behaviour=new.hdf
# Loading: IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new
# Loading: IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new

# %%
# adding now the two best overall:
print('\nSetting categorical data and score samples')
for name, pred_df in preds.items():
    pred_df['channel_code'] = pred_df['channel_code'].astype('category')
    pred_df['location_code'] = pred_df['location_code'].astype('category')
    pred_df['cha_id'] = pred_df['channel_code'].str[:2]
    pred_df['cha_id'] = pred_df['cha_id'].astype('category')
    pred_df['score_samples'] = -(pred_df['decision_function'] + clfs[name].offset_)
    preds[name] = pred_df

print('\nDone. Predictions dataframes columns:')
print(list(preds.values())[0].columns.tolist())  # one is sufficient
print()
# Out:
# Setting categorical data and score samples
#
# Done. Predictions dataframes columns:
# ['allset_train.id', 'correctly_predicted', 'log_loss', 'decision_function', 'dataset_id', 'subclass', 'window_type', 'channel_code', 'location_code', 'station_id', 'outlier', 'cha_id', 'score_samples']

# %%
from sklearn.metrics import roc_curve

from itertools import cycle
import numpy as np

import numpy as np
from sklearn import metrics

# >>> y = np.array([1, 1, 2, 2])
# >>> pred = np.array([0.1, 0.4, 0.35, 0.8])
# >>> fpr, tpr, thresholds = metrics.roc_curve(y, pred, pos_label=2)
# >>> metrics.auc(fpr, tpr)
# 0.75



def select(df, classes):
    sel = None
    for k, v in classes.items():
        if sel is None:
            sel = v(df)
        else:
            sel |= v(df)
    return df[sel]

# select all classes except inliers (used for training):
classnames = sod_core_dataset.allset_train.classnames[1:]
classes = {_: sod_core_dataset.allset_train.class_selector[_] for _ in classnames}


# from sklearn.metrics.log_loss
print('\nCONFUSION MATRICES AT SEGMENT LEVEL\n')
for name, prd_df in preds.items():

    k = 'score_samples'
    print('\n%s | conf. matrx' % str(name))
    data = []
    for cname, class_selector in classes.items():
        _prd_df = prd_df[class_selector(prd_df)]
        expected_class = _prd_df['outlier'].astype(float)
        if (expected_class == 1).all():
            correctly_predicted = _prd_df['score_samples'] >= 0.5
        elif (expected_class == 0).all():
            correctly_predicted = _prd_df['score_samples'] < 0.5
        else:
            raise ValueError('mixing expected classes for class %s' % cname)
        assert not np.isnan(expected_class).any()
        assert not np.isnan(correctly_predicted).any()
        assert not np.isnan(_prd_df['score_samples']).any()
        log_loss = -np.log10(np.clip(1 - np.abs(expected_class - _prd_df['score_samples']), 1e-15, 1-1e-15))
        # when expected == predicted => log_loss = 1
        # when expected=1 and predicted=0 (or viceversa) => log_loss = 0
        
        # log_loss = np.log10(log_loss)
        # print(log_loss)
        data.append([len(_prd_df), correctly_predicted.sum(), log_loss.mean()])
    print(pd.DataFrame(data, columns=['total', 'correctly predicted', 'mean log loss'], index=list(classes.keys())))
# Out:
# CONFUSION MATRICES AT SEGMENT LEVEL
#
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68695       0.131042
# unlabeled (Me suspicious outl.)    18108                 5582       0.323799
# unlabeled (Me unknown)           1957799              1781208       0.251758
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68601       0.138593
# unlabeled (Me suspicious outl.)    18108                 5500       0.333320
# unlabeled (Me unknown)           1957799              1793504       0.245069
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68608       0.163588
# unlabeled (Me suspicious outl.)    18108                 5512       0.344185
# unlabeled (Me unknown)           1957799              1782079       0.235828
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68548       0.164942
# unlabeled (Me suspicious outl.)    18108                 5460       0.348994
# unlabeled (Me unknown)           1957799              1792566       0.231955
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                69056       0.121535
# unlabeled (Me suspicious outl.)    18108                 6926       0.297179
# unlabeled (Me unknown)           1957799              1665474       0.276320
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                69034       0.112476
# unlabeled (Me suspicious outl.)    18108                 6835       0.293506
# unlabeled (Me unknown)           1957799              1662213       0.280424
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68987       0.146799
# unlabeled (Me suspicious outl.)    18108                 6577       0.312574
# unlabeled (Me unknown)           1957799              1677125       0.263055
#
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68993       0.138732
# unlabeled (Me suspicious outl.)    18108                 6579       0.310670
# unlabeled (Me unknown)           1957799              1668753       0.265369
#
# IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68451       0.134071
# unlabeled (Me suspicious outl.)    18108                 5474       0.332561
# unlabeled (Me unknown)           1957799              1820945       0.241382
#
# IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68426       0.163361
# unlabeled (Me suspicious outl.)    18108                 5376       0.346324
# unlabeled (Me unknown)           1957799              1815011       0.231962
#
# IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68445       0.156878
# unlabeled (Me suspicious outl.)    18108                 5266       0.342439
# unlabeled (Me unknown)           1957799              1827730       0.232711
#
# IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68963       0.148609
# unlabeled (Me suspicious outl.)    18108                 6745       0.307391
# unlabeled (Me unknown)           1957799              1714444       0.262106
#
# IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68948       0.132265
# unlabeled (Me suspicious outl.)    18108                 6540       0.308037
# unlabeled (Me unknown)           1957799              1728664       0.261901
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68585       0.126533
# unlabeled (Me suspicious outl.)    18108                 5709       0.325808
# unlabeled (Me unknown)           1957799              1835824       0.242532
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68498       0.128669
# unlabeled (Me suspicious outl.)    18108                 5724       0.324438
# unlabeled (Me unknown)           1957799              1831940       0.245321
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68593       0.156390
# unlabeled (Me suspicious outl.)    18108                 5741       0.340546
# unlabeled (Me unknown)           1957799              1837392       0.230373
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68557       0.151670
# unlabeled (Me suspicious outl.)    18108                 5711       0.336697
# unlabeled (Me unknown)           1957799              1839406       0.231826
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68936       0.105855
# unlabeled (Me suspicious outl.)    18108                 7123       0.290511
# unlabeled (Me unknown)           1957799              1721997       0.277360
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68945       0.099911
# unlabeled (Me suspicious outl.)    18108                 7200       0.288441
# unlabeled (Me unknown)           1957799              1743213       0.278042
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                68972       0.112605
# unlabeled (Me suspicious outl.)    18108                 7032       0.298290
# unlabeled (Me unknown)           1957799              1761032       0.263971
#
# IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70136                69018       0.128146
# unlabeled (Me suspicious outl.)    18108                 7057       0.301629
# unlabeled (Me unknown)           1957799              1741765       0.262972
#
# IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                68826       0.109296
# unlabeled (Me suspicious outl.)    18108                 6136       0.305529
# unlabeled (Me unknown)           1957796              1847314       0.259210
#
# IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                68806       0.109904
# unlabeled (Me suspicious outl.)    18108                 6071       0.306696
# unlabeled (Me unknown)           1957796              1850325       0.256516
#
# IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                68843       0.131355
# unlabeled (Me suspicious outl.)    18108                 6142       0.325217
# unlabeled (Me unknown)           1957796              1849710       0.239053
#
# IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                68836       0.133756
# unlabeled (Me suspicious outl.)    18108                 6111       0.325598
# unlabeled (Me unknown)           1957796              1850303       0.235539
#
# IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                69213       0.087645
# unlabeled (Me suspicious outl.)    18108                 7656       0.279798
# unlabeled (Me unknown)           1957796              1760960       0.282055
#
# IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                69259       0.090198
# unlabeled (Me suspicious outl.)    18108                 7805       0.277449
# unlabeled (Me unknown)           1957796              1748258       0.284876
#
# IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                69168       0.111326
# unlabeled (Me suspicious outl.)    18108                 7428       0.286121
# unlabeled (Me unknown)           1957796              1779360       0.269093
#
# IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new | conf. matrx
#                                    total  correctly predicted  mean log loss
# outl. (wrong inv)                  70130                69167       0.104155
# unlabeled (Me suspicious outl.)    18108                 7458       0.289078
# unlabeled (Me unknown)           1957796              1775301       0.266803
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-208eee2ca185> in <module>
#      68
#      69 colors = cycle(['r-', 'b-', 'g-', 'y-', 'm-', 'k-'])
# ---> 70 with plotparams({'figure.figsize': (10, 10)}):
#      71     for name, prd_df in preds.items():
#      72
#
# NameError: name 'plotparams' is not defined

# %%
import matplotlib
importlib.reload(matplotlib)
import numpy as np
import matplotlib.pyplot as plt
from contextlib import contextmanager
from collections import defaultdict

# %matplotlib inline

@contextmanager
def plotparams(params):
    '''makes temporarily matplotlib params.
    Make sure to run this after %matplotlib inline.
    For info see https://stackoverflow.com/questions/36367986/how-to-make-inline-plots-in-jupyter-notebook-larger'''
    def_params = {k: plt.rcParams[k] for k in params}
    for k, v in params.items():
        plt.rcParams[k] = v
    try:
        yield
    finally:
        for k, v in def_params.items():
            plt.rcParams[k] = v

            
# roc curve classes ignore the Me suspicious outliers (use only more "sure" classes):
rc_classnames = sod_core_dataset.allset_train.classnames[1], sod_core_dataset.allset_train.classnames[-1] 
rc_classes = {_: sod_core_dataset.allset_train.class_selector[_] for _ in rc_classnames}

#print('Scores of classes: %s' % (str(list(classes.keys()))))

aucs = []

colors = cycle(['r-', 'b-', 'g-', 'y-', 'm-', 'k-'])
with plotparams({'figure.figsize': (10, 10)}):
    for name, prd_df in preds.items():
        
        k = 'score_samples'
#        print('\n%s values of score samples (0 ok, 1=anomaly)' % str(name))
#         data = []
#         for cname, class_selector in classes.items():
#             _prd_df = prd_df[class_selector(prd_df)]
#             data.append((_prd_df[k].min(), _prd_df[k].median(), _prd_df[k].max()))
#         print(pd.DataFrame(data, columns=['min', 'median', 'max'], index=list(classes.keys())))

        roc_df = select(prd_df, rc_classes)
        fpr, tpr, thresholds = roc_curve(roc_df['outlier'] * 1.0, roc_df['score_samples'])
        _ = next(colors)
        plt.plot(fpr, tpr, color=_[0], label=name)
        # print([thresholds[np.argwhere(tpr>=0.9)[-1][0]], thresholds[np.argwhere(fpr<=0.1)[-1][0]]])
        aucs.append([name, metrics.auc(fpr, tpr)])

    print('\nROC curves (only using classes: %s)' % str(rc_classnames))

    plt.ylabel('TPR: inliers correctly classified as inliers (divided by total inliers)')
    plt.xlabel('FPR: outliers NOT correctly classified as outliers (divided by total outliers)')
    plt.legend()
    plt.show()
# Out:
# ROC curves (only using classes: ('outl. (wrong inv)', 'unlabeled (Me unknown)'))
#                                                  name       auc
# 0   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.977402
# 1   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.977170
# 2   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.976930
# 3   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.975993
# 4   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.977325
# 5   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.977346
# 6   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.975772
# 7   IsolationForest?features=psd@0.5sec,psd@5sec&c...  0.976612
# 8   IsolationForest?features=psd@1sec,psd@5sec&con...  0.976522
# 9   IsolationForest?features=psd@1sec,psd@5sec&con...  0.973972
# 10  IsolationForest?features=psd@1sec,psd@5sec&con...  0.975067
# 11  IsolationForest?features=psd@1sec,psd@5sec&con...  0.973552
# 12  IsolationForest?features=psd@1sec,psd@5sec&con...  0.974672
# 13  IsolationForest?features=psd@2sec,psd@5sec&con...  0.977301
# 14  IsolationForest?features=psd@2sec,psd@5sec&con...  0.976966
# 15  IsolationForest?features=psd@2sec,psd@5sec&con...  0.975783
# 16  IsolationForest?features=psd@2sec,psd@5sec&con...  0.975566
# 17  IsolationForest?features=psd@2sec,psd@5sec&con...  0.976430
# 18  IsolationForest?features=psd@2sec,psd@5sec&con...  0.976672
# 19  IsolationForest?features=psd@2sec,psd@5sec&con...  0.976401
# 20  IsolationForest?features=psd@2sec,psd@5sec&con...  0.974565
# 21  IsolationForest?features=psd@5sec&contaminatio...  0.981178
# 22  IsolationForest?features=psd@5sec&contaminatio...  0.981264
# 23  IsolationForest?features=psd@5sec&contaminatio...  0.978857
# 24  IsolationForest?features=psd@5sec&contaminatio...  0.979123
# 25  IsolationForest?features=psd@5sec&contaminatio...  0.980838
# 26  IsolationForest?features=psd@5sec&contaminatio...  0.980877
# 27  IsolationForest?features=psd@5sec&contaminatio...  0.979320
# 28  IsolationForest?features=psd@5sec&contaminatio...  0.979917

# %%
import pandas as pd
df = pd.DataFrame(aucs, columns=['name', 'auc'])
dfsorted = df.sort_values(by=['auc'], ascending=False)
# with pd.set_option('display.max_colwidth',1000):
with pd.option_context('display.max_colwidth', 1000):
    print(dfsorted.to_string(line_width=1000, index=False))
# Out:
# name       auc
#            IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.981264
#            IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.981178
#             IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.980877
#             IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.980838
#              IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.979917
#              IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.979320
#             IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.979123
#             IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.978857
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.977402
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.977346
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.977325
#   IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.977301
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.977170
#   IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.976966
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.976930
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.976672
#   IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.976612
#   IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.976522
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.976430
#     IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.976401
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.975993
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.975783
#   IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.975772
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.975566
#    IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.975067
#     IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.974672
#     IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.974565
#    IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.973972
#     IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.973552

# %%
from sod.core import pdconcat

spreds = {}  # station predictions dataframes

groupcols = ['cha_id', 'dataset_id', 'station_id', 'location_code']
added_cols = ['subclass', 'outlier', 'score_samples', 'decision_function', 'num segs']

print('Creating stations prediction dataframes')
print(groupcols)

for name, prd_df in preds.items():
    prd_df = select(prd_df, classes)
    data = []
    for colz_vals, df in prd_df.groupby(groupcols):
        if df.empty:
            continue
        row = list(colz_vals)
        zum = df['outlier'].sum()
        assert zum == 0 or zum == len(df)
        assert len(pd.unique(df['subclass'])) == 1
        row += [df.iloc[0]['subclass'], df.iloc[0]['outlier'],
                df.score_samples.median(), df.decision_function.median(), len(df)]
        data.append(row)
    spreds[name] = pd.DataFrame(data, columns = groupcols + added_cols)
    # spreds[name] = pdconcat(data)
print('Done')
# Out:
# Creating stations prediction dataframes
# ['cha_id', 'dataset_id', 'station_id', 'location_code']
# Done

# %%
# from sklearn.metrics.log_loss
print('\nCONFUSION MATRICES AT STATION LEVEL\n')
saucs = []

colors = cycle(['r-', 'b-', 'g-', 'y-', 'm-', 'k-'])
with plotparams({'figure.figsize': (10, 10)}):
    for name, prd_df in spreds.items():
        
        k = 'score_samples'
#        print('\n%s values of score samples (0 ok, 1=anomaly)' % str(name))
#         data = []
#         for cname, class_selector in classes.items():
#             _prd_df = prd_df[class_selector(prd_df)]
#             data.append((_prd_df[k].min(), _prd_df[k].median(), _prd_df[k].max()))
#         print(pd.DataFrame(data, columns=['min', 'median', 'max'], index=list(classes.keys())))

        roc_df = select(prd_df, rc_classes)
        fpr, tpr, thresholds = roc_curve(roc_df['outlier'] * 1.0, roc_df['score_samples'])
        _ = next(colors)
        plt.plot(fpr, tpr, color=_[0], label=name)
        # print([thresholds[np.argwhere(tpr>=0.9)[-1][0]], thresholds[np.argwhere(fpr<=0.1)[-1][0]]])
        saucs.append([name, metrics.auc(fpr, tpr)])

    print('\nROC curves (only using classes: %s)' % str(rc_classnames))

    plt.ylabel('TPR: inliers correctly classified as inliers (divided by total inliers)')
    plt.xlabel('FPR: outliers NOT correctly classified as outliers (divided by total outliers)')
    plt.legend()
    plt.show()
# Out:
# CONFUSION MATRICES AT STATION LEVEL
#
#
# ROC curves (only using classes: ('outl. (wrong inv)', 'unlabeled (Me unknown)'))

# %%
sdf = pd.DataFrame(saucs, columns=['name', 'auc'])
sdfsorted = sdf.sort_values(by=['auc'], ascending=False)
# with pd.set_option('display.max_colwidth',1000):
with pd.option_context('display.max_colwidth', 1000):
    print(sdfsorted.to_string(line_width=1000, index=False))
# Out:
# name       auc
#             IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.984312
#             IsolationForest?features=psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.983879
#            IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.983695
#            IsolationForest?features=psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.983683
#              IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.983552
#              IsolationForest?features=psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.983450
#             IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.983424
#             IsolationForest?features=psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.983205
#     IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.981236
#   IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.981074
#   IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.981003
#   IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.980050
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.979565
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.979561
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=200&behaviour=new  0.979418
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.979226
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.979169
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=200&behaviour=new  0.979136
# IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=2048&n_estimators=100&behaviour=new  0.979008
#    IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=2048&n_estimators=100&behaviour=new  0.978910
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.978345
#  IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.978025
#    IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=200&behaviour=new  0.977513
#   IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.977404
#     IsolationForest?features=psd@2sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.976033
#   IsolationForest?features=psd@0.5sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.975845
#     IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=200&behaviour=new  0.975702
#     IsolationForest?features=psd@1sec,psd@5sec&contamination=0.1&max_samples=512&n_estimators=100&behaviour=new  0.975062
#    IsolationForest?features=psd@1sec,psd@5sec&contamination=0.05&max_samples=512&n_estimators=100&behaviour=new  0.974851

# %%
classnames = sod_core_dataset.allset_train.classnames
classes = {_: sod_core_dataset.allset_train.class_selector[_] for _ in classnames}

with plotparams({'figure.figsize': (10, 10)}):
    for name in dfsorted['name'][:10]:
        prd_df = preds[name]
        data = []
        for cname, csel in classes.items():
            data.append(prd_df[csel(prd_df)]['score_samples'])
        plt.hist(data, stacked=False, log=True)  #
        plt.title(name)
        plt.legend(list(classnames))
        plt.show()
#         prd_df_msclf = prd_df[prd_df.outlier != (prd_df.score_samples > 0.5)]
#         print('\n\n%s: %d misclassified (score_samples: 0=ok, 1=anomaly)\n' % (str(name), len(prd_df_msclf)))
#         prd_df_msclf.drop(['decision_function'], 1, inplace=True)
#         print(prd_df_msclf.sort_values(by=['subclass', 'score_samples']).to_string(index=False))

# %%
classnames = sod_core_dataset.allset_train.classnames
classes = {_: sod_core_dataset.allset_train.class_selector[_] for _ in classnames}

with plotparams({'figure.figsize': (10, 10)}):
    for name in sdfsorted['name'][:10]:
        prd_df = spreds[name]
        data = []
        for cname, csel in classes.items():
            data.append(prd_df[csel(prd_df)]['score_samples'])
        plt.hist(data, stacked=False, log=True)  #
        plt.title(name)
        plt.legend(list(classnames))
        plt.grid(True)
        plt.show()
#         prd_df_msclf = prd_df[prd_df.outlier != (prd_df.score_samples > 0.5)]
#         print('\n\n%s: %d misclassified (score_samples: 0=ok, 1=anomaly)\n' % (str(name), len(prd_df_msclf)))
#         prd_df_msclf.drop(['decision_function'], 1, inplace=True)
#         print(prd_df_msclf.sort_values(by=['subclass', 'score_samples']).to_string(index=False))

# %%
colors = cycle(['r-', 'b-', 'g-', 'y-', 'm-', 'k-'])
from collections import defaultdict
# unique station keys mapped to the classifier names for which the station is misclassified:
# many_wrong = defaultdict(list)
# for name, prd_df in spreds.items():   
#     prd_df_msclf = prd_df[prd_df.outlier != (prd_df.score_samples > 0.5)]
#     for data in zip(*[prd_df_msclf[_] for _ in groupcols]):
#         many_wrong[data].append(name)
#         print(data)
#         raise
#     print('\n\n%s: %d misclassified (0 ok, 1=anomaly)\n' % (str(name), len(prd_df_msclf)))
#     print(prd_df_msclf.to_string(index=False))

for name, prd_df in spreds.items():
    prd_df_msclf = prd_df[prd_df.outlier != (prd_df.score_samples > 0.5)]
    print('\n\n%s: %d misclassified (score_samples: 0=ok, 1=anomaly)\n' % (str(name), len(prd_df_msclf)))
    prd_df_msclf.drop(['decision_function'], 1, inplace=True)
    print(prd_df_msclf.sort_values(by=['subclass', 'score_samples']).to_string(index=False))
# Out:
# psd[2,5] 0.1 512: 125 misclassified (score_samples: 0=ok, 1=anomaly)
#
# cha_id  dataset_id  station_id location_code                 subclass  outlier  score_samples  num segs
#    BH           2        3258                                            True       0.433563       712
#    BH           2        3246                unlabeled.maybe.outlier     True       0.408503      1071
#    BH           2         434                unlabeled.maybe.outlier     True       0.409318       665
#    BH           2        3242                unlabeled.maybe.outlier     True       0.409742       601
#    BH           2        1126                unlabeled.maybe.outlier     True       0.410985      2463
#    BH           2        3225                unlabeled.maybe.outlier     True       0.411132       855
#    BH           2        2893                unlabeled.maybe.outlier     True       0.422111       507
#    BH           2        1210                unlabeled.maybe.outlier     True       0.425650      2607
#    BH           2        2713                unlabeled.maybe.outlier     True       0.449003       237
#    BH           2        3506                unlabeled.maybe.outlier     True       0.450131       614
#    BH           2         734            00  unlabeled.maybe.outlier     True       0.473842      1225
#    BH           2        1622                      unlabeled.unknown    False       0.500155      1496
#    BH           2        1609                      unlabeled.unknown    False       0.501491      1235
#    BH           2        2619            60        unlabeled.unknown    False       0.504420       309
#    BH           2        2823                      unlabeled.unknown    False       0.504486        77
#    BH           2        2659            00        unlabeled.unknown    False       0.504568       340
#    BH           2        2619            00        unlabeled.unknown    False       0.506974       310
#    BH           2        1901                      unlabeled.unknown    False       0.508001       667
#    BH           2         615                      unlabeled.unknown    False       0.514251       952
#    BH           2        1953                      unlabeled.unknown    False       0.522407       510
#    BH           2          82                      unlabeled.unknown    False       0.524016        52
#    BH           2        1225                      unlabeled.unknown    False       0.527636        36
#    BH           2         438                      unlabeled.unknown    False       0.540283      1787
#    BH           2        1214                      unlabeled.unknown    False       0.540586      1928
#    BH           2         470                      unlabeled.unknown    False       0.543786      2012
#    BH           2        2729                      unlabeled.unknown    False       0.550593       798
#    BH           2        1034                      unlabeled.unknown    False       0.563283      1176
#    BH           2        1457            04        unlabeled.unknown    False       0.569720       246
#    BH           2        1457            02        unlabeled.unknown    False       0.571339       200
#    BH           2        3153                      unlabeled.unknown    False       0.578042       275
#    BH           2        1938                      unlabeled.unknown    False       0.587227       209
#    BH           2         560            10        unlabeled.unknown    False       0.604417      2227
#    BH           2        2929                      unlabeled.unknown    False       0.610031        17
#    BH           2        1015                      unlabeled.unknown    False       0.633883      1592
#    BH           2        3500                      unlabeled.unknown    False       0.640791      1065
#    BH           2        1440                      unlabeled.unknown    False       0.648846        22
#    BH           2        3701            00        unlabeled.unknown    False       0.652166        16
#    BH           2        1580                      unlabeled.unknown    False       0.655452      1283
#    BH           2        3717                      unlabeled.unknown    False       0.664796        65
#    BH           2        1151                      unlabeled.unknown    False       0.666783       517
#    BH           2        1427                      unlabeled.unknown    False       0.686013        35
#    BH           2        3507                      unlabeled.unknown    False       0.686733      1027
#    BH           2        1342                      unlabeled.unknown    False       0.691039       193
#    BH           2        2927                      unlabeled.unknown    False       0.694117        27
#    BH           2        3541                      unlabeled.unknown    False       0.699471        40
#    BH           2        1444                      unlabeled.unknown    False       0.704468       178
#    BH           2         658                      unlabeled.unknown    False       0.717480       708
#    BH           2         664                      unlabeled.unknown    False       0.717859       217
#    BH           2         643                      unlabeled.unknown    False       0.721245      1036
#    BH           2         641                      unlabeled.unknown    False       0.721389       796
#    BH           2         650                      unlabeled.unknown    False       0.721680      1124
#    BH           2         640                      unlabeled.unknown    False       0.721719      1191
#    BH           2         645                      unlabeled.unknown    False       0.721808       501
#    BH           2         661                      unlabeled.unknown    False       0.722921       679
#    BH           2         651                      unlabeled.unknown    False       0.723276       294
#    BH           2         644                      unlabeled.unknown    False       0.723783       851
#    BH           2         662                      unlabeled.unknown    False       0.723973       279
#    BH           2         648                      unlabeled.unknown    False       0.724736       564
#    BH           2         646                      unlabeled.unknown    False       0.725002       784
#    BH           2         660                      unlabeled.unknown    False       0.725268      1136
#    BH           2         652                      unlabeled.unknown    False       0.726133      1151
#    BH           2         654                      unlabeled.unknown    False       0.726133      1204
#    BH           2         659                      unlabeled.unknown    False       0.726133       512
#    BH           2        3512                      unlabeled.unknown    False       0.726386       580
#    BH           2         642                      unlabeled.unknown    False       0.728734       328
#    BH           2        3055                      unlabeled.unknown    False       0.729131       738
#    BH           2         656                      unlabeled.unknown    False       0.729169      1153
#    BH           2         647                      unlabeled.unknown    False       0.730373       535
#    BH           2        2861                      unlabeled.unknown    False       0.730473       439
#    BH           2         653                      unlabeled.unknown    False       0.734840      1217
#    BH           2        3715                      unlabeled.unknown    False       0.735013        66
#    BH           2         663                      unlabeled.unknown    False       0.736109       222
#    BH           2         657                      unlabeled.unknown    False       0.736283       270
#    BH           2        3716                      unlabeled.unknown    False       0.737911        65
#    BH           2        1428                      unlabeled.unknown    False       0.738153        22
#    BH           2         372                      unlabeled.unknown    False       0.742342      1967
#    BH           2        2928                      unlabeled.unknown    False       0.742739        13
#    BH           2        2863                      unlabeled.unknown    False       0.751223       464
#    BH           2         649                      unlabeled.unknown    False       0.754363       436
#    BH           2        1010                      unlabeled.unknown    False       0.755798      1531
#    BH           2        2860                      unlabeled.unknown    False       0.757516        27
#    BH           2        3516                      unlabeled.unknown    False       0.763949        75
#    BH           2        1337            00        unlabeled.unknown    False       0.769432      1479
#    BH           2        1416                      unlabeled.unknown    False       0.781825       123
#    BH           2        2732                      unlabeled.unknown    False       0.799732       793
#    BH           2        2864                      unlabeled.unknown    False       0.801064       375
#    BH           2        3714                      unlabeled.unknown    False       0.801541        53
#    BH           2        3645                      unlabeled.unknown    False       0.807875       547
#    BH           2        2687            00        unlabeled.unknown    False       0.809803       428
#    BH           2        2904                      unlabeled.unknown    False       0.809803         4
#    BH           2         623            51        unlabeled.unknown    False       0.810769         5
#    BH           2        1061                      unlabeled.unknown    False       0.810769      1712
#    BH           2        2990                      unlabeled.unknown    False       0.810769       623
#    BH           2        3494            01        unlabeled.unknown    False       0.810769       131
#    BH           2        1096                      unlabeled.unknown    False       0.812704       692
#    BH           2        1423                      unlabeled.unknown    False       0.812704       231
#    BH           2        1430                      unlabeled.unknown    False       0.812704        76
#    BH           2        1451                      unlabeled.unknown    False       0.812704        68
#    BH           2        3701            10        unlabeled.unknown    False       0.812704        15
#    BH           2         712                      unlabeled.unknown    False       0.813673      1005
#    BH           2         713                      unlabeled.unknown    False       0.813673      1041
#    BH           2         714                      unlabeled.unknown    False       0.813673      2679
#    BH           2         715                      unlabeled.unknown    False       0.813673      1065
#    BH           2         716                      unlabeled.unknown    False       0.813673       835
#    BH           2         719                      unlabeled.unknown    False       0.813673      1747
#    BH           2         724                      unlabeled.unknown    False       0.813673      1161
#    BH           2         725                      unlabeled.unknown    False       0.813673        32
#    BH           2         726                      unlabeled.unknown    False       0.813673      1355
#    BH           2         730                      unlabeled.unknown    False       0.813673      1978
#    BH           2        1414                      unlabeled.unknown    False       0.813673       263
#    BH           2        1422                      unlabeled.unknown    False       0.813673       214
#    BH           2        1431                      unlabeled.unknown    False       0.813673       144
#    BH           2        1432                      unlabeled.unknown    False       0.813673        94
#    BH           2        1433                      unlabeled.unknown    False       0.813673       157
#    BH           2        1443                      unlabeled.unknown    False       0.813673        54
#    BH           2        1449                      unlabeled.unknown    False       0.813673       406
#    BH           2        1453                      unlabeled.unknown    False       0.813673       180
#    BH           2        1454                      unlabeled.unknown    False       0.813673        91
#    BH           2        1070                      unlabeled.unknown    False       0.819900      2750
#    BH           2        1071                      unlabeled.unknown    False       0.819900      2310
#    BH           2        3727                      unlabeled.unknown    False       0.819900        55
#    BH           2        3728                      unlabeled.unknown    False       0.819900        66
#    BH           2        3729                      unlabeled.unknown    False       0.819900       436
#    BH           2        3730                      unlabeled.unknown    False       0.819900       147
#    BH           2        3731                      unlabeled.unknown    False       0.819900       111
#
#
# psd[2,5] 0.05 2048: 116 misclassified (score_samples: 0=ok, 1=anomaly)
#
# cha_id  dataset_id  station_id location_code                 subclass  outlier  score_samples  num segs
#    BH           2        3258                                            True       0.421911       712
#    BH           2         434                unlabeled.maybe.outlier     True       0.403418       665
#    BH           2        1126                unlabeled.maybe.outlier     True       0.405394      2463
#    BH           2        3225                unlabeled.maybe.outlier     True       0.408594       855
#    BH           2        3242                unlabeled.maybe.outlier     True       0.409159       601
#    BH           2        3246                unlabeled.maybe.outlier     True       0.412293      1071
#    BH           2        2893                unlabeled.maybe.outlier     True       0.417815       507
#    BH           2        1210                unlabeled.maybe.outlier     True       0.420251      2607
#    BH           2        2713                unlabeled.maybe.outlier     True       0.433112       237
#    BH           2        3506                unlabeled.maybe.outlier     True       0.435524       614
#    BH           2         734            00  unlabeled.maybe.outlier     True       0.454078      1225
#    BH           2        3047                unlabeled.maybe.outlier     True       0.491385       788
#    BH           2        1214                      unlabeled.unknown    False       0.502744      1928
#    BH           2         470                      unlabeled.unknown    False       0.521818      2012
#    BH           2         438                      unlabeled.unknown    False       0.522461      1787
#    BH           2        2729                      unlabeled.unknown    False       0.524242       798
#    BH           2        1034                      unlabeled.unknown    False       0.526213      1176
#    BH           2          82                      unlabeled.unknown    False       0.528759        52
#    BH           2        1457            04        unlabeled.unknown    False       0.547479       246
#    BH           2        1457            02        unlabeled.unknown    False       0.548467       200
#    BH           2        2929                      unlabeled.unknown    False       0.564174        17
#    BH           2        3153                      unlabeled.unknown    False       0.579614       275
#    BH           2         560            10        unlabeled.unknown    False       0.581788      2227
#    BH           2        3500                      unlabeled.unknown    False       0.583737      1065
#    BH           2        1938                      unlabeled.unknown    False       0.594009       209
#    BH           2        1440                      unlabeled.unknown    False       0.594605        22
#    BH           2        3701            00        unlabeled.unknown    False       0.599874        16
#    BH           2        1580                      unlabeled.unknown    False       0.620762      1283
#    BH           2        3717                      unlabeled.unknown    False       0.620965        65
#    BH           2        1015                      unlabeled.unknown    False       0.623661      1592
#    BH           2        3507                      unlabeled.unknown    False       0.635570      1027
#    BH           2        1342                      unlabeled.unknown    False       0.642374       193
#    BH           2        3541                      unlabeled.unknown    False       0.646745        40
#    BH           2        1427                      unlabeled.unknown    False       0.648576        35
#    BH           2        2927                      unlabeled.unknown    False       0.653025        27
#    BH           2        1444                      unlabeled.unknown    False       0.657171       178
#    BH           2         640                      unlabeled.unknown    False       0.664886      1191
#    BH           2         664                      unlabeled.unknown    False       0.665121       217
#    BH           2         643                      unlabeled.unknown    False       0.667423      1036
#    BH           2         641                      unlabeled.unknown    False       0.667513       796
#    BH           2         650                      unlabeled.unknown    False       0.667933      1124
#    BH           2         658                      unlabeled.unknown    False       0.669208       708
#    BH           2         660                      unlabeled.unknown    False       0.669349      1136
#    BH           2         645                      unlabeled.unknown    False       0.669408       501
#    BH           2         661                      unlabeled.unknown    False       0.669632       679
#    BH           2         644                      unlabeled.unknown    False       0.670196       851
#    BH           2         652                      unlabeled.unknown    False       0.670276      1151
#    BH           2         662                      unlabeled.unknown    False       0.670375       279
#    BH           2         654                      unlabeled.unknown    False       0.670676      1204
#    BH           2         656                      unlabeled.unknown    False       0.671667      1153
#    BH           2         651                      unlabeled.unknown    False       0.671715       294
#    BH           2         648                      unlabeled.unknown    False       0.673028       564
#    BH           2         642                      unlabeled.unknown    False       0.673222       328
#    BH           2         659                      unlabeled.unknown    False       0.673579       512
#    BH           2         646                      unlabeled.unknown    False       0.673666       784
#    BH           2        2861                      unlabeled.unknown    False       0.675256       439
#    BH           2        3716                      unlabeled.unknown    False       0.676654        65
#    BH           2         647                      unlabeled.unknown    False       0.677929       535
#    BH           2         653                      unlabeled.unknown    False       0.678284      1217
#    BH           2         663                      unlabeled.unknown    False       0.680591       222
#    BH           2        3715                      unlabeled.unknown    False       0.681308        66
#    BH           2         657                      unlabeled.unknown    False       0.684630       270
#    BH           2        1151                      unlabeled.unknown    False       0.685156       517
#    BH           2         649                      unlabeled.unknown    False       0.708930       436
#    BH           2        1428                      unlabeled.unknown    False       0.714291        22
#    BH           2        2928                      unlabeled.unknown    False       0.720424        13
#    BH           2        2863                      unlabeled.unknown    False       0.721469       464
#    BH           2        3512                      unlabeled.unknown    False       0.721702       580
#    BH           2         372                      unlabeled.unknown    False       0.731449      1967
#    BH           2        2860                      unlabeled.unknown    False       0.732702        27
#    BH           2        1010                      unlabeled.unknown    False       0.734925      1531
#    BH           2        3055                      unlabeled.unknown    False       0.736426       738
#    BH           2        3516                      unlabeled.unknown    False       0.744536        75
#    BH           2        1337            00        unlabeled.unknown    False       0.749209      1479
#    BH           2        1416                      unlabeled.unknown    False       0.761568       123
#    BH           2        2864                      unlabeled.unknown    False       0.769673       375
#    BH           2        3714                      unlabeled.unknown    False       0.776369        53
#    BH           2        2732                      unlabeled.unknown    False       0.782370       793
#    BH           2        3645                      unlabeled.unknown    False       0.803741       547
#    BH           2        2687            00        unlabeled.unknown    False       0.806453       428
#    BH           2        2904                      unlabeled.unknown    False       0.813469         4
#    BH           2        3494            01        unlabeled.unknown    False       0.816214       131
#    BH           2        1061                      unlabeled.unknown    False       0.817393      1712
#    BH           2        2990                      unlabeled.unknown    False       0.817393       623
#    BH           2         623            51        unlabeled.unknown    False       0.824901         5
#    BH           2        1096                      unlabeled.unknown    False       0.825695       692
#    BH           2        3701            10        unlabeled.unknown    False       0.827286        15
#    BH           2         712                      unlabeled.unknown    False       0.828083      1005
#    BH           2         713                      unlabeled.unknown    False       0.828083      1041
#    BH           2         714                      unlabeled.unknown    False       0.828083      2679
#    BH           2         715                      unlabeled.unknown    False       0.828083      1065
#    BH           2         716                      unlabeled.unknown    False       0.828083       835
#    BH           2         719                      unlabeled.unknown    False       0.828083      1747
#    BH           2         724                      unlabeled.unknown    False       0.828083      1161
#    BH           2         725                      unlabeled.unknown    False       0.828083        32
#    BH           2         726                      unlabeled.unknown    False       0.828083      1355
#    BH           2         730                      unlabeled.unknown    False       0.828083      1978
#    BH           2        1414                      unlabeled.unknown    False       0.828083       263
#    BH           2        1422                      unlabeled.unknown    False       0.828083       214
#    BH           2        1423                      unlabeled.unknown    False       0.828083       231
#    BH           2        1430                      unlabeled.unknown    False       0.828083        76
#    BH           2        1431                      unlabeled.unknown    False       0.828083       144
#    BH           2        1432                      unlabeled.unknown    False       0.828083        94
#    BH           2        1433                      unlabeled.unknown    False       0.828083       157
#    BH           2        1443                      unlabeled.unknown    False       0.828083        54
#    BH           2        1449                      unlabeled.unknown    False       0.828083       406
#    BH           2        1451                      unlabeled.unknown    False       0.828083        68
#    BH           2        1453                      unlabeled.unknown    False       0.828083       180
#    BH           2        1454                      unlabeled.unknown    False       0.828083        91
#    BH           2        1070                      unlabeled.unknown    False       0.831277      2750
#    BH           2        1071                      unlabeled.unknown    False       0.831277      2310
#    BH           2        3727                      unlabeled.unknown    False       0.831277        55
#    BH           2        3728                      unlabeled.unknown    False       0.831277        66
#    BH           2        3729                      unlabeled.unknown    False       0.831277       436
#    BH           2        3730                      unlabeled.unknown    False       0.831277       147
#    BH           2        3731                      unlabeled.unknown    False       0.831277       111
#
#
# psd[5] 0.1 512: 139 misclassified (score_samples: 0=ok, 1=anomaly)
#
# cha_id  dataset_id  station_id location_code                 subclass  outlier  score_samples  num segs
#    BH           2        3258                                            True       0.471042       712
#    BH           2        3242                unlabeled.maybe.outlier     True       0.419075       601
#    BH           2        3225                unlabeled.maybe.outlier     True       0.419980       855
#    BH           2        1126                unlabeled.maybe.outlier     True       0.420898      2463
#    BH           2        1210                unlabeled.maybe.outlier     True       0.424041      2607
#    BH           2         434                unlabeled.maybe.outlier     True       0.426641       665
#    BH           2        3246                unlabeled.maybe.outlier     True       0.428731      1071
#    BH           2        2893                unlabeled.maybe.outlier     True       0.458462       507
#    BH           2        2713                unlabeled.maybe.outlier     True       0.473941       237
#    BH           2        3506                unlabeled.maybe.outlier     True       0.486101       614
#    BH           2         734            00  unlabeled.maybe.outlier     True       0.492608      1225
#    BH           2         540            00        unlabeled.unknown    False       0.500834      1505
#    BH           2        2823                      unlabeled.unknown    False       0.501690        77
#    BH           2        3011                      unlabeled.unknown    False       0.504276       827
#    BH           2        1447                      unlabeled.unknown    False       0.504778        73
#    BH           2         168                      unlabeled.unknown    False       0.505816        43
#    BH           2        1951                      unlabeled.unknown    False       0.507904       517
#    BH           2         459                      unlabeled.unknown    False       0.508299       140
#    BH           2        3055                      unlabeled.unknown    False       0.508702       738
#    BH           2        3078                      unlabeled.unknown    False       0.510913        85
#    BH           2        2659            00        unlabeled.unknown    False       0.512634       340
#    BH           2          34                      unlabeled.unknown    False       0.514007        52
#    BH           2        2926                      unlabeled.unknown    False       0.515264         7
#    BH           2        3074                      unlabeled.unknown    False       0.517320       242
#    BH           2        1610                      unlabeled.unknown    False       0.517770      1316
#    BH           2        1332            00        unlabeled.unknown    False       0.518394      1047
#    BH           2        2506            00        unlabeled.unknown    False       0.518404        67
#    BH           2        1452                      unlabeled.unknown    False       0.518552         1
#    BH           2        2619            60        unlabeled.unknown    False       0.519110       309
#    BH           2        2619            00        unlabeled.unknown    False       0.519141       310
#    BH           2        2686            00        unlabeled.unknown    False       0.519189       323
#    BH           2        1225                      unlabeled.unknown    False       0.522691        36
#    BH           2        3014                      unlabeled.unknown    False       0.530446       787
#    BH           2        1901                      unlabeled.unknown    False       0.532030       667
#    BH           2        2507            10        unlabeled.unknown    False       0.532680        28
#    BH           2        3013                      unlabeled.unknown    False       0.537257       787
#    BH           2        1622                      unlabeled.unknown    False       0.539006      1496
#    BH           2        1953                      unlabeled.unknown    False       0.539951       510
#    BH           2          82                      unlabeled.unknown    False       0.555003        52
#    BH           2        1034                      unlabeled.unknown    False       0.580997      1176
#    BH           2         470                      unlabeled.unknown    False       0.590159      2012
#    BH           2        1938                      unlabeled.unknown    False       0.595677       209
#    BH           2        2729                      unlabeled.unknown    False       0.601171       798
#    BH           2        1457            04        unlabeled.unknown    False       0.612178       246
#    BH           2        1457            02        unlabeled.unknown    False       0.612904       200
#    BH           2         438                      unlabeled.unknown    False       0.617643      1787
#    BH           2        1440                      unlabeled.unknown    False       0.628570        22
#    BH           2        2929                      unlabeled.unknown    False       0.632176        17
#    BH           2        3500                      unlabeled.unknown    False       0.666957      1065
#    BH           2        3153                      unlabeled.unknown    False       0.675954       275
#    BH           2        3701            00        unlabeled.unknown    False       0.679797        16
#    BH           2        3717                      unlabeled.unknown    False       0.696098        65
#    BH           2        1444                      unlabeled.unknown    False       0.698229       178
#    BH           2        1580                      unlabeled.unknown    False       0.704813      1283
#    BH           2        1427                      unlabeled.unknown    False       0.714892        35
#    BH           2        2927                      unlabeled.unknown    False       0.715745        27
#    BH           2        3507                      unlabeled.unknown    False       0.716756      1027
#    BH           2        1342                      unlabeled.unknown    False       0.719796       193
#    BH           2        2928                      unlabeled.unknown    False       0.721598        13
#    BH           2        1015                      unlabeled.unknown    False       0.722782      1592
#    BH           2        3541                      unlabeled.unknown    False       0.730604        40
#    BH           2        1428                      unlabeled.unknown    False       0.738356        22
#    BH           2         660                      unlabeled.unknown    False       0.747557      1136
#    BH           2         640                      unlabeled.unknown    False       0.749118      1191
#    BH           2         372                      unlabeled.unknown    False       0.751159      1967
#    BH           2         664                      unlabeled.unknown    False       0.754719       217
#    BH           2         643                      unlabeled.unknown    False       0.754944      1036
#    BH           2         641                      unlabeled.unknown    False       0.755169       796
#    BH           2         658                      unlabeled.unknown    False       0.755282       708
#    BH           2         650                      unlabeled.unknown    False       0.755394      1124
#    BH           2         652                      unlabeled.unknown    False       0.755394      1151
#    BH           2         653                      unlabeled.unknown    False       0.755394      1217
#    BH           2         645                      unlabeled.unknown    False       0.755845       501
#    BH           2         661                      unlabeled.unknown    False       0.755845       679
#    BH           2         644                      unlabeled.unknown    False       0.756746       851
#    BH           2         662                      unlabeled.unknown    False       0.757649       279
#    BH           2         651                      unlabeled.unknown    False       0.759231       294
#    BH           2         656                      unlabeled.unknown    False       0.759231      1153
#    BH           2         642                      unlabeled.unknown    False       0.759683       328
#    BH           2        1151                      unlabeled.unknown    False       0.759939       517
#    BH           2         646                      unlabeled.unknown    False       0.760136       784
#    BH           2         654                      unlabeled.unknown    False       0.760136      1204
#    BH           2         648                      unlabeled.unknown    False       0.762906       564
#    BH           2         659                      unlabeled.unknown    False       0.765411       512
#    BH           2        3715                      unlabeled.unknown    False       0.766438        66
#    BH           2         647                      unlabeled.unknown    False       0.766552       535
#    BH           2        2861                      unlabeled.unknown    False       0.767695       439
#    BH           2         663                      unlabeled.unknown    False       0.769642       222
#    BH           2        3716                      unlabeled.unknown    False       0.769986        65
#    BH           2        3512                      unlabeled.unknown    False       0.772959       580
#    BH           2        1010                      unlabeled.unknown    False       0.773590      1531
#    BH           2         657                      unlabeled.unknown    False       0.777179       270
#    BH           2        1416                      unlabeled.unknown    False       0.777982       123
#    BH           2        3516                      unlabeled.unknown    False       0.778214        75
#    BH           2        1337            00        unlabeled.unknown    False       0.785670      1479
#    BH           2         649                      unlabeled.unknown    False       0.791906       436
#    BH           2        2732                      unlabeled.unknown    False       0.793433       793
#    BH           2        2863                      unlabeled.unknown    False       0.805231       464
#    BH           2        2860                      unlabeled.unknown    False       0.808597        27
#    BH           2        3645                      unlabeled.unknown    False       0.809433       547
#    BH           2        2687            00        unlabeled.unknown    False       0.810398       428
#    BH           2        2904                      unlabeled.unknown    False       0.811123         4
#    BH           2        1061                      unlabeled.unknown    False       0.812332      1712
#    BH           2        2990                      unlabeled.unknown    False       0.812332       623
#    BH           2        3494            01        unlabeled.unknown    False       0.812332       131
#    BH           2         623            51        unlabeled.unknown    False       0.813059         5
#    BH           2        1096                      unlabeled.unknown    False       0.813059       692
#    BH           2        3701            10        unlabeled.unknown    False       0.814514        15
#    BH           2        2864                      unlabeled.unknown    False       0.816344       375
#    BH           2         712                      unlabeled.unknown    False       0.816701      1005
#    BH           2         713                      unlabeled.unknown    False       0.816701      1041
#    BH           2         714                      unlabeled.unknown    False       0.816701      2679
#    BH           2         715                      unlabeled.unknown    False       0.816701      1065
#    BH           2         716                      unlabeled.unknown    False       0.816701       835
#    BH           2         719                      unlabeled.unknown    False       0.816701      1747
#    BH           2         724                      unlabeled.unknown    False       0.816701      1161
#    BH           2         725                      unlabeled.unknown    False       0.816701        32
#    BH           2         726                      unlabeled.unknown    False       0.816701      1355
#    BH           2         730                      unlabeled.unknown    False       0.816701      1978
#    BH           2        1414                      unlabeled.unknown    False       0.816701       263
#    BH           2        1422                      unlabeled.unknown    False       0.816701       214
#    BH           2        1423                      unlabeled.unknown    False       0.816701       231
#    BH           2        1430                      unlabeled.unknown    False       0.816701        76
#    BH           2        1431                      unlabeled.unknown    False       0.816701       144
#    BH           2        1432                      unlabeled.unknown    False       0.816701        94
#    BH           2        1433                      unlabeled.unknown    False       0.816701       157
#    BH           2        1443                      unlabeled.unknown    False       0.816701        54
#    BH           2        1449                      unlabeled.unknown    False       0.816701       406
#    BH           2        1451                      unlabeled.unknown    False       0.816701        68
#    BH           2        1453                      unlabeled.unknown    False       0.816701       180
#    BH           2        1454                      unlabeled.unknown    False       0.816701        91
#    BH           2        3714                      unlabeled.unknown    False       0.820979        53
#    BH           2        1070                      unlabeled.unknown    False       0.829092      2750
#    BH           2        1071                      unlabeled.unknown    False       0.829092      2310
#    BH           2        3727                      unlabeled.unknown    False       0.829092        55
#    BH           2        3728                      unlabeled.unknown    False       0.829092        66
#    BH           2        3729                      unlabeled.unknown    False       0.829092       436
#    BH           2        3730                      unlabeled.unknown    False       0.829092       147
#    BH           2        3731                      unlabeled.unknown    False       0.829092       111
#
#
# psd[5] 0.05 2048: 115 misclassified (score_samples: 0=ok, 1=anomaly)
#
# cha_id  dataset_id  station_id location_code                 subclass  outlier  score_samples  num segs
#    BH           2        3258                                            True       0.466372       712
#    BH           2        1126                unlabeled.maybe.outlier     True       0.422798      2463
#    BH           2        3242                unlabeled.maybe.outlier     True       0.424005       601
#    BH           2        3225                unlabeled.maybe.outlier     True       0.425040       855
#    BH           2        1210                unlabeled.maybe.outlier     True       0.426590      2607
#    BH           2         434                unlabeled.maybe.outlier     True       0.427203       665
#    BH           2        3246                unlabeled.maybe.outlier     True       0.432478      1071
#    BH           2        2713                unlabeled.maybe.outlier     True       0.458973       237
#    BH           2        2893                unlabeled.maybe.outlier     True       0.462137       507
#    BH           2        3506                unlabeled.maybe.outlier     True       0.471324       614
#    BH           2         734            00  unlabeled.maybe.outlier     True       0.473142      1225
#    BH           2        3013                      unlabeled.unknown    False       0.500753       787
#    BH           2        1622                      unlabeled.unknown    False       0.503502      1496
#    BH           2        1953                      unlabeled.unknown    False       0.506897       510
#    BH           2          82                      unlabeled.unknown    False       0.507507        52
#    BH           2        1034                      unlabeled.unknown    False       0.520852      1176
#    BH           2        1938                      unlabeled.unknown    False       0.526606       209
#    BH           2         470                      unlabeled.unknown    False       0.535903      2012
#    BH           2        2729                      unlabeled.unknown    False       0.536480       798
#    BH           2        1457            04        unlabeled.unknown    False       0.556464       246
#    BH           2        1457            02        unlabeled.unknown    False       0.557389       200
#    BH           2         438                      unlabeled.unknown    False       0.557829      1787
#    BH           2        1440                      unlabeled.unknown    False       0.567130        22
#    BH           2        2929                      unlabeled.unknown    False       0.570845        17
#    BH           2        3500                      unlabeled.unknown    False       0.606470      1065
#    BH           2        3701            00        unlabeled.unknown    False       0.620007        16
#    BH           2        3153                      unlabeled.unknown    False       0.623370       275
#    BH           2        3717                      unlabeled.unknown    False       0.625470        65
#    BH           2        3507                      unlabeled.unknown    False       0.637268      1027
#    BH           2        1342                      unlabeled.unknown    False       0.643761       193
#    BH           2        3541                      unlabeled.unknown    False       0.656728        40
#    BH           2        1444                      unlabeled.unknown    False       0.662931       178
#    BH           2        1580                      unlabeled.unknown    False       0.675549      1283
#    BH           2         660                      unlabeled.unknown    False       0.682767      1136
#    BH           2        1427                      unlabeled.unknown    False       0.685972        35
#    BH           2         640                      unlabeled.unknown    False       0.686060      1191
#    BH           2        2927                      unlabeled.unknown    False       0.687293        27
#    BH           2         664                      unlabeled.unknown    False       0.690504       217
#    BH           2        2928                      unlabeled.unknown    False       0.692273        13
#    BH           2         643                      unlabeled.unknown    False       0.693001      1036
#    BH           2        1015                      unlabeled.unknown    False       0.694107      1592
#    BH           2         641                      unlabeled.unknown    False       0.695171       796
#    BH           2         658                      unlabeled.unknown    False       0.695171       708
#    BH           2         650                      unlabeled.unknown    False       0.695437      1124
#    BH           2         652                      unlabeled.unknown    False       0.695437      1151
#    BH           2         645                      unlabeled.unknown    False       0.696511       501
#    BH           2         653                      unlabeled.unknown    False       0.696511      1217
#    BH           2         661                      unlabeled.unknown    False       0.696511       679
#    BH           2         644                      unlabeled.unknown    False       0.699197       851
#    BH           2         662                      unlabeled.unknown    False       0.701557       279
#    BH           2         656                      unlabeled.unknown    False       0.702232      1153
#    BH           2         651                      unlabeled.unknown    False       0.702570       294
#    BH           2         642                      unlabeled.unknown    False       0.703078       328
#    BH           2         654                      unlabeled.unknown    False       0.703247      1204
#    BH           2         646                      unlabeled.unknown    False       0.703585       784
#    BH           2         648                      unlabeled.unknown    False       0.706299       564
#    BH           2        1428                      unlabeled.unknown    False       0.708012        22
#    BH           2         659                      unlabeled.unknown    False       0.708682       512
#    BH           2        3715                      unlabeled.unknown    False       0.710774        66
#    BH           2         647                      unlabeled.unknown    False       0.711145       535
#    BH           2        2861                      unlabeled.unknown    False       0.715616       439
#    BH           2         663                      unlabeled.unknown    False       0.717342       222
#    BH           2         372                      unlabeled.unknown    False       0.718528      1967
#    BH           2        3716                      unlabeled.unknown    False       0.719068        65
#    BH           2         657                      unlabeled.unknown    False       0.723580       270
#    BH           2        1151                      unlabeled.unknown    False       0.739181       517
#    BH           2         649                      unlabeled.unknown    False       0.740605       436
#    BH           2        1010                      unlabeled.unknown    False       0.747768      1531
#    BH           2        2863                      unlabeled.unknown    False       0.755000       464
#    BH           2        1416                      unlabeled.unknown    False       0.757183       123
#    BH           2        3516                      unlabeled.unknown    False       0.757547        75
#    BH           2        3512                      unlabeled.unknown    False       0.762840       580
#    BH           2        1337            00        unlabeled.unknown    False       0.764873      1479
#    BH           2        2860                      unlabeled.unknown    False       0.768563        27
#    BH           2        2732                      unlabeled.unknown    False       0.776743       793
#    BH           2        2864                      unlabeled.unknown    False       0.791840       375
#    BH           2        3714                      unlabeled.unknown    False       0.808785        53
#    BH           2        3645                      unlabeled.unknown    False       0.818574       547
#    BH           2        2687            00        unlabeled.unknown    False       0.826490       428
#    BH           2        2904                      unlabeled.unknown    False       0.832680         4
#    BH           2        1061                      unlabeled.unknown    False       0.836091      1712
#    BH           2        3494            01        unlabeled.unknown    False       0.836091       131
#    BH           2        2990                      unlabeled.unknown    False       0.836896       623
#    BH           2         623            51        unlabeled.unknown    False       0.841743         5
#    BH           2        1096                      unlabeled.unknown    False       0.842148       692
#    BH           2        1070                      unlabeled.unknown    False       0.844177      2750
#    BH           2        1071                      unlabeled.unknown    False       0.844177      2310
#    BH           2        3727                      unlabeled.unknown    False       0.844177        55
#    BH           2        3728                      unlabeled.unknown    False       0.844177        66
#    BH           2        3729                      unlabeled.unknown    False       0.844177       436
#    BH           2        3730                      unlabeled.unknown    False       0.844177       147
#    BH           2        3731                      unlabeled.unknown    False       0.844177       111
#    BH           2        3701            10        unlabeled.unknown    False       0.844584        15
#    BH           2         712                      unlabeled.unknown    False       0.845397      1005
#    BH           2         713                      unlabeled.unknown    False       0.845397      1041
#    BH           2         714                      unlabeled.unknown    False       0.845397      2679
#    BH           2         715                      unlabeled.unknown    False       0.845397      1065
#    BH           2         716                      unlabeled.unknown    False       0.845397       835
#    BH           2         719                      unlabeled.unknown    False       0.845397      1747
#    BH           2         724                      unlabeled.unknown    False       0.845397      1161
#    BH           2         725                      unlabeled.unknown    False       0.845397        32
#    BH           2         726                      unlabeled.unknown    False       0.845397      1355
#    BH           2         730                      unlabeled.unknown    False       0.845397      1978
#    BH           2        1414                      unlabeled.unknown    False       0.845397       263
#    BH           2        1422                      unlabeled.unknown    False       0.845397       214
#    BH           2        1423                      unlabeled.unknown    False       0.845397       231
#    BH           2        1430                      unlabeled.unknown    False       0.845397        76
#    BH           2        1431                      unlabeled.unknown    False       0.845397       144
#    BH           2        1432                      unlabeled.unknown    False       0.845397        94
#    BH           2        1433                      unlabeled.unknown    False       0.845397       157
#    BH           2        1443                      unlabeled.unknown    False       0.845397        54
#    BH           2        1449                      unlabeled.unknown    False       0.845397       406
#    BH           2        1451                      unlabeled.unknown    False       0.845397        68
#    BH           2        1453                      unlabeled.unknown    False       0.845397       180
#    BH           2        1454                      unlabeled.unknown    False       0.845397        91

# %%
# adding now the two best overall:
import time
from sod.core.evaluation import _predict
# clfs = {k: load(os.path.join(root, 'models', v + '.model')) for k, v in fnames.items()}

fnames.append()

with plotparams({'figure.figsize': (10, 10)}):

    print('\nPerformances')

    numinst = (100, 1000, 10000, 100000)
    dfs = {_: dataframe.iloc[np.random.randint(0, len(dataframe), _)].dropna() for _ in numinst}
    print('\nEstimating performances')
    for name, clf in clfs.items():
        feats = fnames[name]
        feats = feats[feats.find('features=') + len('features='):].split('&')[0].split(',')
        # print(feats)
        plotdata = []
        for test in numinst:
            ints = np.random.randint(0, len(dataframe), test)
            # dataf = dataframe.iloc[ints]
            test_df = dfs[test][feats]
            t = time.time()
            #print(dataf[feats])
            # raise
            prd = _predict(clf, test_df)
            t = time.time() - t
            plotdata.append(t)
        plt.plot(numinst, plotdata, label=fnames[name])
    plt.xlabel('Number of instances')
    plt.ylabel('time required (seconds)')
    plt.legend()
plt.show()
# Out:
# Performances
#
# Estimating performances

# %%
# fare un boxplot asse x: tempo, asse y: score_samples
