# %%
import os
import numpy as np
import pandas as pd
from sklearn.metrics import roc_curve, auc

def roc(pred_df):
    fpr, tpr, thresholds = roc_curve(pred_df.outlier, pred_df.predicted_anomaly_score, drop_intermediate=True)
    auc_ = auc(fpr, tpr)
    tnr_, tpr_, th_ = (1-fpr[1:]), tpr[1:], thresholds[1:]  # thresholds[0] represents no instances being predicted and is arbitrarily set to max(y_score) + 1.
    pos, neg = pred_df.outlier.sum(), (~pred_df.outlier).sum()
    best_th = np.argmax(tnr_ * tpr_)
    return {
        'auc': auc_,
        'best_thres': th_[best_th],
        'best_thres_tpr': tpr_[best_th],
        'best_thres_tnr': tnr_[best_th]
    }

import sys
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from sod.core.dataset import dataset_info, allset_test

class_inlier = allset_test.classnames[0]
class_outlier = allset_test.classnames[1]
class_me_unknown = allset_test.classnames[2]

sel_inlier = allset_test.class_selector[class_inlier]
sel_outlier = allset_test.class_selector[class_outlier]
sel_me_unknown = allset_test.class_selector[class_me_unknown]


print()
print('Loading models and predictions')
maindir = os.path.abspath(os.path.join(os.getcwd(), '..',
                                       'evaluations/results/eval.allset_train_test.iforest.yaml/evalreports/'))
assert os.path.isdir(maindir)
rootdir = maindir.replace('evalreports', '')
modeldir = os.path.join(rootdir, 'models')
predir = os.path.join(rootdir, 'predictions')
assert os.path.isdir(modeldir)
assert os.path.isdir(predir)

auc_df = None

data = []
index = []
modelfiles = os.listdir(modeldir)
last_progress = -1
for i, clfname in enumerate(modelfiles):
    progress = int((100.0*i)/len(modelfiles))
    if int(progress/10) != int(last_progress/10):
        print('%d%% done' % progress)
        last_progress = progress
#     if 'features=psd@5sec' not in clfname: # and 'features=psd@2sec,psd@5sec' not in clfname:
#         continue
    o_pred_df =  pd.read_hdf(os.path.join(predir, clfname.replace('.model', '.hdf')))
    pred_df = o_pred_df[sel_inlier(o_pred_df) | sel_outlier(o_pred_df)]
    row = roc(pred_df)
    row['classifier'] = clfname[:clfname.index('?')]
    flatname = clfname[clfname.index('?')+1:].replace('.model', '')
    for pnamepval in flatname.split('&'):
        pname, pval = pnamepval.split('=')
        try:
            row[pname] = int(pval)
        except:
            try:
                row[pname] = float(pval)
            except:
                row[pname] = pval
    data.append(row)
    # index.append(clfname.replace('.model', '').replace('&behaviour=new&contamination=auto', '').replace('IsolationForest?', ''))

auc_df = pd.DataFrame(data=data)
print('Summary stats (auc, tpr tnr) on predictions (evaluations)')
with pd.option_context("display.max_colwidth", 80):
    print(auc_df.sort_values(by=['auc'], ascending=False).to_string(index=False))

hdfpath = os.path.join(maindir, 'evaluation.auc.all.hdf') 
print('Saving to "%s"' % hdfpath)

auc_df.to_hdf(hdfpath, mode='w', format='table', key='evaluation_all_auc')
# Out:
# Loading models and predictions
# 10% done
# 20% done
# 30% done
# 40% done
# 50% done
# 60% done
# 70% done
# 80% done
# 90% done
# Summary stats (auc, tpr tnr) on predictions (evaluations)
# auc behaviour  best_thres  best_thres_tnr  best_thres_tpr       classifier contamination                                          features  max_samples  n_estimators
# 0.994533       new    0.516447        0.992397        0.971725  IsolationForest          auto                                          psd@5sec         2048           200
# 0.994291       new    0.520936        0.992429        0.972020  IsolationForest          auto                                          psd@5sec         2048           100
# 0.994114       new    0.557885        0.992898        0.971763  IsolationForest          auto                                          psd@5sec          512           200
# 0.994020       new    0.564893        0.993282        0.971439  IsolationForest          auto                                          psd@5sec          512           100
# 0.993958       new    0.526618        0.993804        0.970098  IsolationForest          auto                                          psd@5sec         2048            50
# 0.993706       new    0.562603        0.993346        0.970726  IsolationForest          auto                                          psd@5sec          512            50
# 0.993473       new    0.492309        0.993964        0.970335  IsolationForest          auto                                          psd@5sec         8192           200
# 0.993375       new    0.525974        0.992098        0.967709  IsolationForest          auto                               psd@0.2sec,psd@5sec         8192           100
# 0.993294       new    0.514302        0.991064        0.972334  IsolationForest          auto                               psd@0.2sec,psd@5sec         8192           200
# 0.993278       new    0.565973        0.986159        0.970773  IsolationForest          auto                               psd@0.2sec,psd@5sec          512            50
# 0.993166       new    0.503115        0.993858        0.970450  IsolationForest          auto                                          psd@5sec         8192           100
# 0.993067       new    0.535828        0.988910        0.971668  IsolationForest          auto                               psd@0.2sec,psd@5sec         2048           200
# 0.993055       new    0.512010        0.991203        0.968404  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         2048            50
# 0.992993       new    0.519781        0.990424        0.966643  IsolationForest          auto                               psd@0.2sec,psd@5sec         8192            50
# 0.992851       new    0.508472        0.995084        0.968775  IsolationForest          auto                                          psd@5sec         8192            50
# 0.992827       new    0.574748        0.989742        0.972391  IsolationForest          auto                               psd@0.2sec,psd@5sec          512           100
# 0.992752       new    0.568494        0.990637        0.972420  IsolationForest          auto                               psd@0.2sec,psd@5sec          512           200
# 0.992711       new    0.524893        0.992941        0.968404  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         2048           100
# 0.992580       new    0.539372        0.988334        0.972972  IsolationForest          auto                               psd@0.2sec,psd@5sec         2048           100
# 0.992536       new    0.523327        0.992045        0.966576  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         2048           200
# 0.992381       new    0.495740        0.991704        0.968499  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         8192           200
# 0.992350       new    0.545714        0.991064        0.968375  IsolationForest          auto                               psd@0.2sec,psd@5sec         2048            50
# 0.992225       new    0.537839        0.991107        0.967813  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec          512           200
# 0.992097       new    0.501388        0.988323        0.970126  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         8192           100
# 0.992091       new    0.538595        0.990563        0.966196  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec          512           100
# 0.992069       new    0.493200        0.989870        0.969622  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         8192           200
# 0.992064       new    0.490818        0.990040        0.968394  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         8192           200
# 0.992056       new    0.528104        0.990936        0.965862  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         2048           200
# 0.992040       new    0.505013        0.992674        0.962760  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         2048           200
# 0.991992       new    0.502838        0.990787        0.967033  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         8192           100
# 0.991900       new    0.521797        0.990637        0.966243  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         2048           200
# 0.991876       new    0.531781        0.990669        0.964911  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         2048           100
# 0.991853       new    0.541778        0.991277        0.957021  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec          512            50
# 0.991829       new    0.523104        0.989038        0.966443  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         2048            50
# 0.991797       new    0.530509        0.993271        0.966414  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         2048           100
# 0.991776       new    0.544224        0.989347        0.963483  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec          512           200
# 0.991757       new    0.542408        0.983866        0.968204  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec          512           200
# 0.991726       new    0.542851        0.984079        0.961532  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec          512            50
# 0.991711       new    0.544896        0.986447        0.966900  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec          512           100
# 0.991631       new    0.476354        0.988985        0.967281  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         8192           200
# 0.991616       new    0.502685        0.987289        0.966824  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec         8192            50
# 0.991615       new    0.500971        0.989795        0.962617  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         2048           100
# 0.991614       new    0.547698        0.985434        0.966319  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec          512           100
# 0.991583       new    0.520218        0.990435        0.964692  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         2048            50
# 0.991400       new    0.477875        0.988067        0.966748  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         8192           200
# 0.991351       new    0.505236        0.989368        0.963616  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         2048           200
# 0.991334       new    0.493122        0.989699        0.957716  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         8192           100
# 0.991324       new    0.499760        0.991181        0.969374  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         8192            50
# 0.991322       new    0.549030        0.984325        0.956907  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@5sec          512            50
# 0.991310       new    0.533798        0.992472        0.971173  IsolationForest          auto                                 psd@2sec,psd@5sec          512           200
# 0.991214       new    0.508296        0.993175        0.962532  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@5sec         8192            50
# 0.991203       new    0.483971        0.987652        0.956869  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192           100
# 0.991086       new    0.496424        0.989443        0.972210  IsolationForest          auto                      psd@0.2sec,psd@2sec,psd@5sec         8192           100
# 0.991072       new    0.532892        0.988867        0.961247  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec          512           200
# 0.991069       new    0.525017        0.995319        0.964207  IsolationForest          auto                                 psd@2sec,psd@5sec         2048           200
# 0.991047       new    0.553157        0.995319        0.968299  IsolationForest          auto                                 psd@2sec,psd@5sec          512           100
# 0.990963       new    0.548534        0.994615        0.968622  IsolationForest          auto                                 psd@2sec,psd@5sec          512            50
# 0.990938       new    0.505386        0.991416        0.959048  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         2048            50
# 0.990862       new    0.561239        0.992525        0.967947  IsolationForest          auto                               psd@0.5sec,psd@5sec          512           200
# 0.990844       new    0.485046        0.987417        0.965263  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         8192           100
# 0.990841       new    0.536465        0.988771        0.956602  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec          512           100
# 0.990784       new    0.507819        0.989539        0.958763  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         2048           200
# 0.990766       new    0.490573        0.988355        0.952929  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         8192            50
# 0.990740       new    0.536200        0.987630        0.961171  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec          512           200
# 0.990734       new    0.523509        0.987374        0.963036  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec          512           200
# 0.990733       new    0.491659        0.991394        0.956174  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         8192           100
# 0.990722       new    0.484403        0.986031        0.967680  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         8192            50
# 0.990693       new    0.568179        0.993346        0.966919  IsolationForest          auto                               psd@0.5sec,psd@5sec          512           100
# 0.990648       new    0.476555        0.989379        0.957564  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192           200
# 0.990543       new    0.509115        0.993005        0.962341  IsolationForest          auto                                 psd@2sec,psd@5sec         8192           100
# 0.990515       new    0.567701        0.992152        0.963750  IsolationForest          auto                               psd@0.5sec,psd@5sec          512            50
# 0.990453       new    0.525029        0.985711        0.959486  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec          512           100
# 0.990446       new    0.528386        0.994284        0.965767  IsolationForest          auto                                 psd@2sec,psd@5sec         2048           100
# 0.990414       new    0.541711        0.997046        0.962227  IsolationForest          auto                                 psd@2sec,psd@5sec         2048            50
# 0.990383       new    0.486206        0.990339        0.961751  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         8192           200
# 0.990376       new    0.511441        0.988494        0.962589  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         2048           100
# 0.990372       new    0.535986        0.993111        0.965615  IsolationForest          auto                               psd@0.5sec,psd@5sec         2048           200
# 0.990341       new    0.503405        0.994636        0.963321  IsolationForest          auto                                 psd@2sec,psd@5sec         8192           200
# 0.990235       new    0.509021        0.992503        0.966786  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         2048            50
# 0.990203       new    0.475376        0.981008        0.949322  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192            50
# 0.990191       new    0.491403        0.988697        0.952206  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec         8192            50
# 0.990131       new    0.499339        0.989016        0.956069  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048           200
# 0.990121       new    0.535993        0.988441        0.954842  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec          512            50
# 0.989996       new    0.516064        0.993271        0.961066  IsolationForest          auto                                 psd@2sec,psd@5sec         8192            50
# 0.989979       new    0.508573        0.989038        0.968461  IsolationForest          auto                               psd@0.5sec,psd@5sec         8192            50
# 0.989967       new    0.541936        0.994615        0.963550  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec          512           200
# 0.989959       new    0.512550        0.988089        0.955698  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         2048           100
# 0.989953       new    0.520943        0.994892        0.964321  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         2048           100
# 0.989896       new    0.512457        0.993325        0.964977  IsolationForest          auto                               psd@0.5sec,psd@5sec         8192           200
# 0.989889       new    0.519692        0.992717        0.964968  IsolationForest          auto                               psd@0.5sec,psd@5sec         8192           100
# 0.989869       new    0.495997        0.986980        0.956974  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048            50
# 0.989850       new    0.508970        0.987950        0.961922  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@2sec,psd@5sec         2048            50
# 0.989818       new    0.528183        0.986788        0.954918  IsolationForest          auto             psd@0.2sec,psd@1sec,psd@2sec,psd@5sec          512            50
# 0.989807       new    0.535682        0.990925        0.963331  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec          512           100
# 0.989769       new    0.554639        0.995521        0.963826  IsolationForest          auto                                 psd@1sec,psd@5sec          512            50
# 0.989764       new    0.500793        0.987033        0.955822  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048           100
# 0.989728       new    0.506624        0.990445        0.968108  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         2048           200
# 0.989615       new    0.533892        0.991309        0.967518  IsolationForest          auto                               psd@0.5sec,psd@5sec         2048            50
# 0.989573       new    0.523246        0.983461        0.947428  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512           200
# 0.989572       new    0.492720        0.992770        0.964264  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         8192           200
# 0.989540       new    0.537659        0.984399        0.955527  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec          512           100
# 0.989438       new    0.542898        0.992973        0.966205  IsolationForest          auto                               psd@0.5sec,psd@5sec         2048           100
# 0.989415       new    0.540830        0.993581        0.964387  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec          512           100
# 0.989382       new    0.521426        0.980592        0.948646  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512           100
# 0.989237       new    0.555818        0.996033        0.964778  IsolationForest          auto                                 psd@1sec,psd@5sec          512           200
# 0.989224       new    0.535398        0.992749        0.962655  IsolationForest          auto                                 psd@1sec,psd@5sec         2048            50
# 0.989110       new    0.519735        0.991832        0.963026  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         2048            50
# 0.989083       new    0.561011        0.995895        0.964530  IsolationForest          auto                                 psd@1sec,psd@5sec          512           100
# 0.989073       new    0.502299        0.994231        0.965986  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         8192           100
# 0.989069       new    0.538567        0.995767        0.959638  IsolationForest          auto                                 psd@1sec,psd@5sec         2048           200
# 0.989052       new    0.546268        0.995617        0.960200  IsolationForest          auto                                 psd@1sec,psd@5sec         2048           100
# 0.989026       new    0.540197        0.994999        0.964264  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec          512           200
# 0.989011       new    0.509063        0.994338        0.960733  IsolationForest          auto                                 psd@1sec,psd@5sec         8192           200
# 0.989001       new    0.553456        0.988089        0.941756  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec          512            50
# 0.988879       new    0.548029        0.993197        0.960504  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec          512           200
# 0.988874       new    0.525637        0.993101        0.963407  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         2048           100
# 0.988814       new    0.509066        0.985082        0.952091  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@5sec         2048            50
# 0.988793       new    0.495241        0.992002        0.963540  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         8192           100
# 0.988712       new    0.552255        0.992599        0.958687  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec          512           100
# 0.988605       new    0.530426        0.990360        0.957716  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec          512            50
# 0.988484       new    0.517924        0.994146        0.958144  IsolationForest          auto                                 psd@1sec,psd@5sec         8192           100
# 0.988358       new    0.480832        0.991554        0.958239  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192           200
# 0.988355       new    0.504700        0.992493        0.962922  IsolationForest          auto                      psd@0.5sec,psd@2sec,psd@5sec         8192            50
# 0.988342       new    0.520190        0.992525        0.963264  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         2048           200
# 0.988313       new    0.489695        0.992578        0.958344  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192           100
# 0.988296       new    0.512823        0.973618        0.947561  IsolationForest          auto  psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512            50
# 0.988282       new    0.510324        0.991160        0.960837  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         2048            50
# 0.988183       new    0.507258        0.991778        0.963198  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         2048           100
# 0.988179       new    0.525342        0.990136        0.964473  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec          512            50
# 0.988168       new    0.517794        0.993261        0.957145  IsolationForest          auto                                 psd@1sec,psd@5sec         8192            50
# 0.988155       new    0.502913        0.991789        0.963093  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         2048           200
# 0.988105       new    0.490956        0.991384        0.962179  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         8192           200
# 0.988093       new    0.530424        0.992365        0.961475  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512           200
# 0.987993       new    0.546022        0.988782        0.957963  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec          512            50
# 0.987907       new    0.498921        0.991757        0.959553  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@5sec         8192            50
# 0.987834       new    0.487217        0.991832        0.956098  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         8192            50
# 0.987813       new    0.497495        0.991778        0.960152  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048           200
# 0.987751       new    0.521473        0.991192        0.959562  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512            50
# 0.987625       new    0.494173        0.992845        0.960600  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         8192           100
# 0.987583       new    0.475630        0.990221        0.965472  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         8192           200
# 0.987513       new    0.493584        0.991416        0.960999  IsolationForest          auto                        psd@1sec,psd@2sec,psd@5sec         8192            50
# 0.987395       new    0.523773        0.989390        0.963093  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec          512           100
# 0.986940       new    0.497689        0.989848        0.960352  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048           100
# 0.986672       new    0.498675        0.990062        0.961742  IsolationForest          auto             psd@0.5sec,psd@1sec,psd@2sec,psd@5sec         2048            50
# 0.986072       new    0.525772        0.979419        0.930745  IsolationForest          auto                                          psd@2sec          512           100
# 0.985945       new    0.522962        0.978513        0.931135  IsolationForest          auto                                          psd@2sec          512           200
# 0.985121       new    0.501331        0.983567        0.918173  IsolationForest          auto                                          psd@2sec         2048           200
# 0.984861       new    0.526088        0.979697        0.930906  IsolationForest          auto                                          psd@2sec          512            50
# 0.984383       new    0.489653        0.983887        0.919496  IsolationForest          auto                                          psd@2sec         8192           200
# 0.984221       new    0.518724        0.989219        0.912586  IsolationForest          auto                                          psd@2sec         2048           100
# 0.983610       new    0.502454        0.976892        0.920638  IsolationForest          auto                                          psd@2sec         2048            50
# 0.982527       new    0.488410        0.978897        0.917868  IsolationForest          auto                                          psd@2sec         8192           100
# 0.980692       new    0.503039        0.994370        0.894180  IsolationForest          auto                                          psd@2sec         8192            50
# 0.978592       new    0.517708        0.968766        0.909103  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec          512            50
# 0.978488       new    0.520494        0.961782        0.909455  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec          512           100
# 0.977497       new    0.527427        0.965322        0.902127  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec          512           200
# 0.976694       new    0.531673        0.965407        0.904868  IsolationForest          auto                               psd@0.2sec,psd@2sec          512           200
# 0.976641       new    0.478042        0.966666        0.908656  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         8192           100
# 0.976621       new    0.531196        0.962144        0.905867  IsolationForest          auto                               psd@0.2sec,psd@2sec          512           100
# 0.976602       new    0.547731        0.983343        0.907438  IsolationForest          auto                               psd@0.5sec,psd@2sec          512           100
# 0.976439       new    0.519361        0.967668        0.909712  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec          512           200
# 0.976181       new    0.496501        0.962880        0.905506  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         2048           100
# 0.975877       new    0.539744        0.980187        0.908332  IsolationForest          auto                               psd@0.5sec,psd@2sec          512           200
# 0.975188       new    0.496499        0.964874        0.903440  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         2048           200
# 0.975033       new    0.469950        0.964288        0.900928  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         8192           200
# 0.974962       new    0.528171        0.967988        0.900642  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec          512           100
# 0.974943       new    0.531751        0.969033        0.908922  IsolationForest          auto                               psd@0.5sec,psd@2sec          512            50
# 0.974427       new    0.527051        0.970814        0.914404  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec          512           100
# 0.974296       new    0.499331        0.966079        0.894761  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         2048            50
# 0.974264       new    0.479443        0.965343        0.904992  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@2sec         8192            50
# 0.974249       new    0.533921        0.972083        0.895199  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec          512           100
# 0.974202       new    0.520674        0.971358        0.912929  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec          512           200
# 0.973792       new    0.526851        0.963626        0.901508  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec          512            50
# 0.973689       new    0.528690        0.971709        0.895322  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec          512           200
# 0.973678       new    0.529545        0.979398        0.909598  IsolationForest          auto                                 psd@1sec,psd@2sec          512           200
# 0.973435       new    0.524664        0.957953        0.892591  IsolationForest          auto                               psd@0.2sec,psd@2sec          512            50
# 0.973398       new    0.484264        0.965237        0.895989  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         2048           200
# 0.973383       new    0.527290        0.972861        0.913100  IsolationForest          auto                                 psd@1sec,psd@2sec          512           100
# 0.972956       new    0.478616        0.958188        0.900281  IsolationForest          auto                               psd@0.2sec,psd@2sec         8192           200
# 0.972707       new    0.528523        0.966495        0.898634  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec          512            50
# 0.972313       new    0.530320        0.970974        0.906172  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec          512            50
# 0.972099       new    0.518823        0.963360        0.915156  IsolationForest          auto                                 psd@1sec,psd@2sec          512            50
# 0.972006       new    0.502142        0.977073        0.911654  IsolationForest          auto                                 psd@1sec,psd@2sec         2048            50
# 0.971678       new    0.456384        0.953955        0.898111  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         8192           200
# 0.971546       new    0.465673        0.954061        0.904287  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         8192           100
# 0.970849       new    0.510115        0.966986        0.883702  IsolationForest          auto                               psd@0.2sec,psd@2sec         2048           200
# 0.970817       new    0.509766        0.965887        0.890849  IsolationForest          auto                               psd@0.2sec,psd@2sec         2048           100
# 0.970615       new    0.464804        0.968894        0.902689  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         8192           200
# 0.970461       new    0.505575        0.974023        0.897454  IsolationForest          auto                               psd@0.5sec,psd@2sec         2048           200
# 0.970267       new    0.484663        0.952611        0.891497  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         2048           100
# 0.969780       new    0.474224        0.972808        0.889346  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         8192           100
# 0.969751       new    0.477573        0.967679        0.903773  IsolationForest          auto                               psd@0.5sec,psd@2sec         8192           200
# 0.969572       new    0.496551        0.968990        0.885377  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         2048           200
# 0.969501       new    0.510175        0.982043        0.900462  IsolationForest          auto                                 psd@1sec,psd@2sec         2048           100
# 0.969347       new    0.462928        0.956333        0.893990  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         8192           200
# 0.969335       new    0.504646        0.972509        0.900424  IsolationForest          auto                               psd@0.5sec,psd@2sec         2048           100
# 0.969256       new    0.503823        0.976497        0.890840  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         2048           100
# 0.969245       new    0.550128        0.974983        0.869931  IsolationForest          auto                                          psd@1sec          512           200
# 0.969091       new    0.546451        0.970014        0.885444  IsolationForest          auto                                          psd@1sec          512           100
# 0.969036       new    0.467699        0.969779        0.890469  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         8192            50
# 0.969008       new    0.492942        0.965557        0.875146  IsolationForest          auto                               psd@0.2sec,psd@2sec         8192           100
# 0.968979       new    0.499645        0.974418        0.900319  IsolationForest          auto                                 psd@1sec,psd@2sec         2048           200
# 0.968692       new    0.467614        0.952718        0.896893  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         8192            50
# 0.968660       new    0.484296        0.949177        0.880999  IsolationForest          auto           psd@0.2sec,psd@0.5sec,psd@1sec,psd@2sec         2048            50
# 0.968612       new    0.499683        0.955490        0.890840  IsolationForest          auto                               psd@0.2sec,psd@2sec         2048            50
# 0.968559       new    0.496876        0.972051        0.896579  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         2048           200
# 0.968526       new    0.496463        0.964799        0.887223  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         2048           100
# 0.968107       new    0.504255        0.976508        0.871930  IsolationForest          auto                      psd@0.2sec,psd@1sec,psd@2sec         2048            50
# 0.967762       new    0.500476        0.972488        0.889945  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         2048            50
# 0.967669       new    0.475911        0.971688        0.898787  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         8192           100
# 0.967363       new    0.505646        0.961814        0.877164  IsolationForest          auto                                          psd@1sec         8192           100
# 0.967016       new    0.483258        0.957559        0.897768  IsolationForest          auto                               psd@0.5sec,psd@2sec         8192           100
# 0.966658       new    0.514717        0.926112        0.891401  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec          512            50
# 0.966376       new    0.508853        0.955298        0.873709  IsolationForest          auto                                          psd@1sec         2048           200
# 0.966373       new    0.506474        0.910415        0.904897  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec          512           100
# 0.966346       new    0.524955        0.942022        0.892943  IsolationForest          auto                               psd@0.5sec,psd@1sec          512           100
# 0.966310       new    0.517559        0.942779        0.877373  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec          512           200
# 0.965683       new    0.475508        0.971560        0.889726  IsolationForest          auto                                 psd@1sec,psd@2sec         8192           200
# 0.965267       new    0.460845        0.924278        0.895237  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         8192           100
# 0.964989       new    0.516901        0.966122        0.873881  IsolationForest          auto                                          psd@1sec         2048           100
# 0.964750       new    0.485494        0.930900        0.880590  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         2048           100
# 0.964687       new    0.484210        0.932510        0.880419  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         2048           200
# 0.964479       new    0.528800        0.957452        0.876260  IsolationForest          auto                               psd@0.5sec,psd@1sec          512           200
# 0.964356       new    0.551227        0.962635        0.878944  IsolationForest          auto                                          psd@1sec          512            50
# 0.964299       new    0.501696        0.968148        0.893581  IsolationForest          auto                               psd@0.5sec,psd@2sec         2048            50
# 0.964296       new    0.519362        0.940124        0.886072  IsolationForest          auto                               psd@0.5sec,psd@1sec          512            50
# 0.964127       new    0.485843        0.974386        0.888737  IsolationForest          auto                                 psd@1sec,psd@2sec         8192           100
# 0.964121       new    0.458961        0.934376        0.877697  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         8192           200
# 0.963966       new    0.462863        0.924480        0.891744  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         8192            50
# 0.962858       new    0.526597        0.965418        0.867190  IsolationForest          auto                                          psd@1sec         2048            50
# 0.962519       new    0.490035        0.962240        0.871501  IsolationForest          auto                               psd@0.2sec,psd@2sec         8192            50
# 0.962493       new    0.509574        0.919159        0.880190  IsolationForest          auto                               psd@0.2sec,psd@1sec          512           200
# 0.962329       new    0.499204        0.962464        0.836479  IsolationForest          auto                                          psd@1sec         8192           200
# 0.962304       new    0.514417        0.920993        0.876802  IsolationForest          auto                               psd@0.2sec,psd@1sec          512           100
# 0.961748       new    0.475685        0.964245        0.892030  IsolationForest          auto                      psd@0.5sec,psd@1sec,psd@2sec         8192            50
# 0.961272       new    0.488343        0.965674        0.885710  IsolationForest          auto                               psd@0.5sec,psd@2sec         8192            50
# 0.960694       new    0.479239        0.938524        0.864839  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         8192           200
# 0.960389       new    0.478424        0.924523        0.876155  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         8192           100
# 0.960383       new    0.508535        0.974450        0.845663  IsolationForest          auto                                          psd@1sec         8192            50
# 0.960279       new    0.480784        0.916067        0.876583  IsolationForest          auto                    psd@0.2sec,psd@0.5sec,psd@1sec         2048            50
# 0.959514       new    0.518309        0.921697        0.871863  IsolationForest          auto                             psd@0.2sec,psd@0.5sec          512           200
# 0.959427       new    0.529130        0.932478        0.862289  IsolationForest          auto                             psd@0.2sec,psd@0.5sec          512           100
# 0.958159       new    0.492879        0.917506        0.873205  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         2048           200
# 0.957941       new    0.499358        0.946885        0.857844  IsolationForest          auto                               psd@0.5sec,psd@1sec         2048           200
# 0.957921       new    0.494303        0.938311        0.875232  IsolationForest          auto                               psd@0.5sec,psd@1sec         2048           100
# 0.957823       new    0.508638        0.922444        0.860338  IsolationForest          auto                               psd@0.2sec,psd@1sec          512            50
# 0.956992       new    0.474130        0.942214        0.854485  IsolationForest          auto                               psd@0.5sec,psd@1sec         8192           200
# 0.956945       new    0.494044        0.918434        0.868542  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         2048           100
# 0.955928       new    0.485332        0.925984        0.859405  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         8192            50
# 0.955833       new    0.490474        0.930847        0.848137  IsolationForest          auto                               psd@0.2sec,psd@1sec         2048           200
# 0.955478       new    0.483873        0.971326        0.871901  IsolationForest          auto                                 psd@1sec,psd@2sec         8192            50
# 0.955265       new    0.467185        0.919799        0.860033  IsolationForest          auto                               psd@0.2sec,psd@1sec         8192           200
# 0.954678       new    0.498176        0.942641        0.861442  IsolationForest          auto                               psd@0.5sec,psd@1sec         2048            50
# 0.954137       new    0.493372        0.926475        0.853438  IsolationForest          auto                             psd@0.2sec,psd@0.5sec         2048            50
# 0.954052       new    0.516063        0.915939        0.862917  IsolationForest          auto                             psd@0.2sec,psd@0.5sec          512            50
# 0.953102       new    0.473125        0.924438        0.866410  IsolationForest          auto                               psd@0.5sec,psd@1sec         8192           100
# 0.952409       new    0.479966        0.937458        0.845006  IsolationForest          auto                               psd@0.5sec,psd@1sec         8192            50
# 0.952200       new    0.494900        0.933694        0.836203  IsolationForest          auto                               psd@0.2sec,psd@1sec         2048           100
# 0.948624       new    0.561658        0.975047        0.822841  IsolationForest          auto                                        psd@0.5sec          512           100
# 0.948116       new    0.553157        0.975410        0.823574  IsolationForest          auto                                        psd@0.5sec          512           200
# 0.948020       new    0.485265        0.944827        0.806110  IsolationForest          auto                               psd@0.2sec,psd@1sec         8192           100
# 0.946084       new    0.487390        0.922700        0.829293  IsolationForest          auto                               psd@0.2sec,psd@1sec         2048            50
# 0.943046       new    0.531316        0.969491        0.818606  IsolationForest          auto                                        psd@0.5sec         2048           200
# 0.942152       new    0.555804        0.976476        0.824478  IsolationForest          auto                                        psd@0.5sec          512            50
# 0.941754       new    0.510693        0.955426        0.831340  IsolationForest          auto                                        psd@0.5sec         8192           100
# 0.940989       new    0.551031        0.981136        0.795337  IsolationForest          auto                                        psd@0.5sec         2048           100
# 0.939616       new    0.481737        0.947364        0.795299  IsolationForest          auto                               psd@0.2sec,psd@1sec         8192            50
# 0.937335       new    0.509808        0.968937        0.811458  IsolationForest          auto                                        psd@0.5sec         8192           200
# 0.935370       new    0.516479        0.961600        0.821946  IsolationForest          auto                                        psd@0.5sec         8192            50
# 0.935209       new    0.538035        0.957761        0.812648  IsolationForest          auto                                        psd@0.5sec         2048            50
# 0.873257       new    0.511359        0.964160        0.723207  IsolationForest          auto                                        psd@0.2sec         8192           200
# 0.872477       new    0.561451        0.960001        0.721656  IsolationForest          auto                                        psd@0.2sec          512           200
# 0.870331       new    0.542418        0.971859        0.712025  IsolationForest          auto                                        psd@0.2sec         2048           200
# 0.867213       new    0.575217        0.967508        0.719029  IsolationForest          auto                                        psd@0.2sec          512           100
# 0.861362       new    0.564054        0.960481        0.721094  IsolationForest          auto                                        psd@0.2sec          512            50
# 0.858934       new    0.543833        0.971720        0.709350  IsolationForest          auto                                        psd@0.2sec         2048           100
# 0.851911       new    0.529763        0.980464        0.700167  IsolationForest          auto                                        psd@0.2sec         8192            50
# 0.845746       new    0.515845        0.964106        0.713528  IsolationForest          auto                                        psd@0.2sec         8192           100
# 0.842237       new    0.554544        0.978801        0.705591  IsolationForest          auto                                        psd@0.2sec         2048            50
# Saving to "/data/home/rizac/work/gfz/projects/sources/python/sod/sod/evaluations/results/eval.allset_train_test.iforest.yaml/evalreports/evaluation.auc.all.hdf"
